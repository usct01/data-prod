# %%
import pandas as pd
from pathlib import Path

# %%
datapath1 = Path('/content/drive/MyDrive/json150')
datapath2 = Path('/content/drive/MyDrive/json_115')

# %%
file_list1= list(datapath2.glob('*.json'))
file_list2= list(datapath2.glob('*.json'))
file_list = file_list1 + file_list2
len(file_list),file_list[0]
# Out:
# (188,
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_13_49_18.json'))

# %%
import json
json_data=[]
good_file=[]
bad_file=[]
for file in file_list:
    try:
        # print(file)
        f = open(file)
        data = json.load(f)
        json_data.append(data)
        good_file.append(file)
    except:
        bad_file.append(file)
    f.close()

print(len(json_data))
# print(len(bad_file))
print(f"Good files: {len(good_file)}, Bad files: {len(bad_file)}")
# json_data
# Out:
# 186
# Good files: 186, Bad files: 2

# %%
list(bad_file)
# Out:
# [PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_10_37_32_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_10_37_32_timestamped.json')]

# %%
##above bad_file do not contain any data

# %%
df=pd.json_normalize(json_data)

# %% [markdown]
# #combining all data to data frame

# %%
df.head()
# Out:
#   Metadata       Caller                           Receiver  \
# 0    value        Emily  Crafton Family Practice (Kumaran)
# 1    value      no_name  Crafton Family Practice (dominic)
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice)
# 3    value     Ed Jones  Dominic (Crofton Family Practice)
# 4    value    Elizabeth  Kumaran (Crofton Family Practice)
#
#               Timestamp                     CallContent.Seq1.CallerContent  \
# 0  2023_Dec_04_13:49:18  Hi, I just want to double check. My daughter h...
# 1  2023_Dec_04_14:46:53  last known thanks for calling corruption from ...
# 2  2023_Dec_04_15:24:59  I'd like to speak out with the front office ab...
# 3   2023_12_04_14:59:14  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4   2023_12_04_14:51:12                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ... CallContent.Seq52.ReceiverContent  \
# 0       2023_Dec_04_13:49:32  ...                               NaN
# 1       2023_Dec_04_14:46:53  ...                               NaN
# 2       2023_Dec_04_15:24:59  ...                               NaN
# 3        2023_12_04_14:59:14  ...                               NaN
# 4        2023_12_04_14:51:12  ...                               NaN
#
#   CallContent.Seq52.Timestamp CallContent.Seq53.ReceiverContent  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#   CallContent.Seq53.Timestamp CallContent.Seq54.CallerContent  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#   CallContent.Seq54.ReceiverContent CallContent.Seq54.Timestamp  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#   CallContent.Seq11.OtherSpeakerContent CallContent.Seq5.OtherSpeakerContent  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   Content
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 181 columns]

# %%
df=pd.json_normalize(json_data)
df['Timestamp']=df['Timestamp'].str.replace("_","-",2)
df['Timestamp']=df['Timestamp'].str.replace("_"," ",1)
df['Timestamp']=df['Timestamp'].str.replace("_",":",2)
df['Timestamp']=pd.to_datetime(df['Timestamp'],format='mixed',errors='coerce')
df['Timestamp']=pd.to_datetime(df['Timestamp']).dt.normalize()
df['call_weekday'] = df['Timestamp'].dt.day_name()
df['call_month'] = df['Timestamp'].dt.month_name()
df['CallerContent']=df.loc[:,(df.columns.str.endswith('CallerContent'))].apply(lambda x: ' '.join(x.dropna().astype(str).values),axis=1)
df['ReceiverContent']=df.loc[:,(df.columns.str.endswith('ReceiverContent'))].apply(lambda x: ' '.join(x.dropna().astype(str).values),axis=1)

print(df.isna().sum())
print(df[['CallerContent','ReceiverContent']])
df.sample(10)
# Out:
# Metadata                           54
# Caller                             50
# Receiver                           10
# Timestamp                          14
# CallContent.Seq1.CallerContent     88
#                                  ...
# Content                           178
# call_weekday                       14
# call_month                         14
# CallerContent                       0
# ReceiverContent                     0
# Length: 185, dtype: int64
#                                          CallerContent  \
# 0    Hi, I just want to double check. My daughter h...
# 1    last known thanks for calling corruption from ...
# 2    I'd like to speak out with the front office ab...
# 3    Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4    Hello? Yes, I'd like to make an appointment fo...
# ..                                                 ...
# 181
# 182  You sent me to the front office. She put me on...
# 183
# 184  Hi, yes. I'd like to make an appointment with ...
# 185  Good morning. My name is Mary Shealy, and I ne...
#
#                                        ReceiverContent
# 0    Good afternoon, this is Crafton Family Practic...
# 1    is this you for the day hi I was wondering if ...
# 2    Good afternoon. Thanks for calling Grafton Fam...
# 3    Good afternoon. Thanks for calling Crofton Fam...
# 4    Good afternoon, this is Kumaran from Family Pr...
# ..                                                 ...
# 181
# 182  No, ma'am. It's not like that. Yes, she was on...
# 183
# 184  Good morning. Thanks for calling Carlson Famil...
# 185  Would you like to meet the doctor in person, o...
#
# [186 rows x 2 columns]
#     Metadata           Caller                             Receiver  Timestamp  \
# 96     value         Ed Jones    Dominic (Crofton Family Practice) 2023-12-04
# 41     value     Dr. Williams                              Dominic 2023-09-20
# 51     value             Alan                              Dominic 2023-09-21
# 182      NaN    Marilyn Hardy                              Dominic 2023-09-20
# 36     value   Roberta Nelson                              Dominic 2023-09-20
# 29       NaN  Marlene Delaney                                Kumar 2024-03-27
# 168    value              NaN  Dominic from Robson Family Practice 2023-09-21
# 128      NaN          Michael                                Kumar 2024-03-27
# 119    value              Kim                                Kumar 2023-10-26
# 109    value   John K. Miller    Dominic (Crofton Family Practice) 2023-11-01
#
#                         CallContent.Seq1.CallerContent  \
# 96   Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 41                                                 NaN
# 51                                                 NaN
# 182  You sent me to the front office. She put me on...
# 36   Yeah, this is Roberta Nelson. I need to resche...
# 29   Good morning, my name is Marlene Delaney. To s...
# 168                                                NaN
# 128  Good morning. I'd like to schedule a physical ...
# 119         Hi Kumar. This is Kim Bussey. How are you?
# 109  Hi, good morning. I need to cancel a November ...
#
#                       CallContent.Seq1.ReceiverContent  \
# 96   Good afternoon. Thanks for calling Crofton Fam...
# 41   Good afternoon. Thanks for calling Crofton Fam...
# 51   Good morning. Thank you for calling Crofton Fa...
# 182  No, ma'am. It's not like that. Yes, she was on...
# 36   Okay, so you want to reschedule the appointmen...
# 29   Okay, one moment. I'm going to transfer you to...
# 168  Good afternoon. Thank you for calling Robson F...
# 128  For you both. One moment. Could I take your da...
# 119  Good morning. Thank you for calling Garofalo F...
# 109  Good morning. Thank you for calling Crofton Fa...
#
#     CallContent.Seq1.Timestamp  \
# 96         2023_12_04_14:59:14
# 41         2023-09-20 16:08:46
# 51         2023-09-21 09:05:10
# 182        2023-09-20 10:03:04
# 36         2023-09-20 15:13:31
# 29         2024-03-27 00:16:00
# 168        2023-09-21 00:00:00
# 128        2024-03-27 00:10:00
# 119        2023-10-26 10:04:16
# 109       2023-Nov-01 09:35:20
#
#                         CallContent.Seq2.CallerContent  \
# 96                                    Okay. Thank you.
# 41   Hi there. I was just in to see Dr. Williams an...
# 51   Yeah, this is Alan Smith again. Listen, you we...
# 182  Who am I speaking with? I'm calling because Br...
# 36   Yes, and I'd like it next month. And if you co...
# 29   Thank you for contacting Crawford Family Pract...
# 168                                                NaN
# 128               I think last year's was in December.
# 119                     Okay. Somebody just called me.
# 109  Yeah, he already got it when he was in the oth...
#
#                       CallContent.Seq2.ReceiverContent  \
# 96   Sure. Regarding that, I need to transfer you t...
# 41   Okay. Regarding that, let me transfer the call...
# 51   Okay. So can you please help me with your appo...
# 182  Okay. Let me see what's going on. I'll try to ...
# 36   Yeah, I got you. So may I have your date of bi...
# 29   I'm sorry about that and thank you so much for...
# 168                                                NaN
# 128  You have made your previous physical. It was o...
# 119  I'm doing good. Thanks for asking. How are you...
# 109                                          Yes, sir.
#
#     CallContent.Seq2.Timestamp  ... CallContent.Seq54.CallerContent  \
# 96         2023_12_04_14:59:14  ...                             NaN
# 41         2023-09-20 16:08:54  ...                             NaN
# 51         2023-09-21 09:05:14  ...                             NaN
# 182        2023-09-20 10:03:45  ...                             NaN
# 36         2023-09-20 15:13:35  ...                             NaN
# 29         2024-03-27 00:41:00  ...                             NaN
# 168        2023-09-21 00:05:00  ...                             NaN
# 128        2024-03-27 00:40:00  ...                             NaN
# 119        2023-10-26 10:04:10  ...                             NaN
# 109       2023-Nov-01 09:35:20  ...                             NaN
#
#     CallContent.Seq54.ReceiverContent CallContent.Seq54.Timestamp  \
# 96                                NaN                         NaN
# 41                                NaN                         NaN
# 51                                NaN                         NaN
# 182                               NaN                         NaN
# 36                                NaN                         NaN
# 29                                NaN                         NaN
# 168                               NaN                         NaN
# 128                               NaN                         NaN
# 119                               NaN                         NaN
# 109                               NaN                         NaN
#
#     CallContent.Seq11.OtherSpeakerContent  \
# 96                                    NaN
# 41                                    NaN
# 51                                    NaN
# 182                                   NaN
# 36                                    NaN
# 29                                    NaN
# 168                                   NaN
# 128                                   NaN
# 119                                   NaN
# 109                                   NaN
#
#     CallContent.Seq5.OtherSpeakerContent Content call_weekday call_month  \
# 96                                   NaN     NaN       Monday   December
# 41                                   NaN     NaN    Wednesday  September
# 51                                   NaN     NaN     Thursday  September
# 182                                  NaN     NaN    Wednesday  September
# 36                                   NaN     NaN    Wednesday  September
# 29                                   NaN     NaN    Wednesday      March
# 168                     Thank you. Yeah.     NaN     Thursday  September
# 128                                  NaN     NaN    Wednesday      March
# 119                                  NaN     NaN     Thursday    October
# 109                                  NaN     NaN    Wednesday   November
#
#                                          CallerContent  \
# 96   Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 41   Hi there. I was just in to see Dr. Williams an...
# 51   Yeah, this is Alan Smith again. Listen, you we...
# 182  You sent me to the front office. She put me on...
# 36   Yeah, this is Roberta Nelson. I need to resche...
# 29   Good morning, my name is Marlene Delaney. To s...
# 168  You said Dominic, right? Yeah, this is Michell...
# 128  Good morning. I'd like to schedule a physical ...
# 119  Hi Kumar. This is Kim Bussey. How are you? Oka...
# 109  Hi, good morning. I need to cancel a November ...
#
#                                        ReceiverContent
# 96   Good afternoon. Thanks for calling Crofton Fam...
# 41   Good afternoon. Thanks for calling Crofton Fam...
# 51   Good morning. Thank you for calling Crofton Fa...
# 182  No, ma'am. It's not like that. Yes, she was on...
# 36   Okay, so you want to reschedule the appointmen...
# 29   Okay, one moment. I'm going to transfer you to...
# 168  Good afternoon. Thank you for calling Robson F...
# 128  For you both. One moment. Could I take your da...
# 119  Good morning. Thank you for calling Garofalo F...
# 109  Good morning. Thank you for calling Crofton Fa...
#
# [10 rows x 185 columns]

# %%
df_n1 = pd.DataFrame(columns=['ts'])
df_n1['ts'] = df['CallContent.Seq1.Timestamp']
df_n1
# Out:
#                        ts
# 0    2023_Dec_04_13:49:18
# 1    2023_Dec_04_14:46:53
# 2    2023_Dec_04_15:24:59
# 3     2023_12_04_14:59:14
# 4     2023_12_04_14:51:12
# ..                    ...
# 181                   NaN
# 182   2023-09-20 10:03:04
# 183                   NaN
# 184   2023-10-26 10:04:16
# 185   2024-10-29 00:04:00
#
# [186 rows x 1 columns]

# %%
df_n1['ts']=df_n1['ts'].str.replace("_","-",2)
df_n1['ts']=df_n1['ts'].str.replace("_"," ",1)
df_n1['ts']=df_n1['ts'].str.replace("_",":",2)
df_n1['ts']=pd.to_datetime(df_n1['ts'],format='mixed')

# %%
df_n1
# Out:
#                      ts
# 0   2023-12-04 13:49:18
# 1   2023-12-04 14:46:53
# 2   2023-12-04 15:24:59
# 3   2023-12-04 14:59:14
# 4   2023-12-04 14:51:12
# ..                  ...
# 181                 NaT
# 182 2023-09-20 10:03:04
# 183                 NaT
# 184 2023-10-26 10:04:16
# 185 2024-10-29 00:04:00
#
# [186 rows x 1 columns]

# %%
df_n1['Timezone'] = df_n1['ts'].dt.tz_localize('UTC').dt.tz_convert('America/New_York').dt.hour
df_n1_grouped = df_n1.groupby('Timezone')['ts'].count()
df_n1_grouped_morning = df_n1_grouped[0:9].sum()
df_n1_grouped_afternoon = df_n1_grouped[9:17].sum()
df_n1_grouped_evening = df_n1_grouped[17:24].sum()

print("Total calls in morning:", df_n1_grouped_morning)
print("Total calls in  afternoon:", df_n1_grouped_afternoon)
print("Total calls in evening", df_n1_grouped_evening)
# Out:
# Total calls in morning: 56
# Total calls in  afternoon: 64
# Total calls in evening 56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Columns: 185 entries, Metadata to ReceiverContent
# dtypes: datetime64[ns](1), object(184)
# memory usage: 269.0+ KB

# %%
df.shape
# Out:
# (186, 185)

# %%
df.columns
# Out:
# Index(['Metadata', 'Caller', 'Receiver', 'Timestamp',
#        'CallContent.Seq1.CallerContent', 'CallContent.Seq1.ReceiverContent',
#        'CallContent.Seq1.Timestamp', 'CallContent.Seq2.CallerContent',
#        'CallContent.Seq2.ReceiverContent', 'CallContent.Seq2.Timestamp',
#        ...
#        'CallContent.Seq54.CallerContent', 'CallContent.Seq54.ReceiverContent',
#        'CallContent.Seq54.Timestamp', 'CallContent.Seq11.OtherSpeakerContent',
#        'CallContent.Seq5.OtherSpeakerContent', 'Content', 'call_weekday',
#        'call_month', 'CallerContent', 'ReceiverContent'],
#       dtype='object', length=185)

# %%
len(df.columns)
# Out:
# 185

# %%
df.head()
# Out:
#   Metadata       Caller                           Receiver  Timestamp  \
# 0    value        Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1    value      no_name  Crafton Family Practice (dominic) 2023-12-04
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3    value     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4    value    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
#
#                       CallContent.Seq1.CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ... CallContent.Seq54.CallerContent  \
# 0       2023_Dec_04_13:49:32  ...                             NaN
# 1       2023_Dec_04_14:46:53  ...                             NaN
# 2       2023_Dec_04_15:24:59  ...                             NaN
# 3        2023_12_04_14:59:14  ...                             NaN
# 4        2023_12_04_14:51:12  ...                             NaN
#
#   CallContent.Seq54.ReceiverContent CallContent.Seq54.Timestamp  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#   CallContent.Seq11.OtherSpeakerContent CallContent.Seq5.OtherSpeakerContent  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   Content call_weekday call_month  \
# 0     NaN       Monday   December
# 1     NaN       Monday   December
# 2     NaN       Monday   December
# 3     NaN       Monday   December
# 4     NaN       Monday   December
#
#                                        CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4  Hello? Yes, I'd like to make an appointment fo...
#
#                                      ReceiverContent
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
# [5 rows x 185 columns]

# %% [markdown]
# #Number of calls by person  making the calls

# %%
print(df.Caller.value_counts(ascending = False))
# Out:
# Caller
# Anonymous                   8
# Judith                      6
# Marilyn Hardy               6
# No name                     6
# Unnamed                     4
# Cheryl Naiman               4
# Robert                      4
# No Name                     4
# John Hopkins Imaging        2
# Chris                       2
# Michael                     2
# Roberta Nelson              2
# Alan Smith                  2
# Sandra Arrington            2
# Ms. Watson                  2
# Dr. Williams                2
# Camelia Watson              2
# Mr. Leatherman              2
# No Name (Beverly Cantor)    2
# Latoya                      2
# Allison                     2
# Faith Van Lange             2
# Alan                        2
# Randy                       2
# Ken Brown                   2
# Unknown                     2
# Ellen                       2
# William Taylor              2
# Madonna Simon               2
# Emily                       2
# no_name                     2
# Hartwell Alderson           2
# Brian Fryer                 2
# Ed Jones                    2
# Elizabeth                   2
# Lisa Cunningham             2
# Stephen Chapman             2
# Aquanetta Delaney           2
# Dale Carnett                2
# Patrick Ferguson            2
# Mary Keller                 2
# Anthony Figlio              2
# McKay Godwin                2
# William                     2
# John K. Miller              2
# Ashley                      2
# Joe                         2
# Brandy                      2
# Nathaniel James             2
# Wanda                       2
# Kim                         2
# Rhoda                       2
# Marlene Delaney             2
# Arundel Michael             2
# Mary Shealy                 2
# Name: count, dtype: int64

# %%
print(df.Receiver.value_counts())
# Out:
# Receiver
# Dominic                                  62
# Kumar                                    24
# Dominic (Crofton Family Practice)        10
# Kathy                                     8
# Dominic from Crofton Family Practice      8
# Kumaran (Crofton Family Practice)         6
# Dominique                                 6
# Brandi                                    4
# Brandy                                    4
# Kathy from Crofton Family Practice        4
# Kumar from Crofton Family Practice        4
# Kathy from Crosswind Family Practice      4
# Kumar from Crawford Family Practice       2
# Dominic from Robson Family Practice       2
# No Name                                   2
# Dominic from Grobson Family Practice      2
# Dominic from Coffin Family Practice       2
# Dominic from CrossFit Family Practice     2
# Dominic from Grafton Family Practice      2
# Crafton Family Practice (Kumaran)         2
# Kathy from Proud and Family Practice      2
# Crafton Family Practice (dominic)         2
# Dominic (Crossroads Family Practice)      2
# Kumaran (Robson Family Practice)          2
# Kumaran (Carlston Family Practice)        2
# David (Crossroads Family Practice)        2
# Kumaran (Grafton Family Practice)         2
# Carole                                    2
# Name: count, dtype: int64

# %% [markdown]
# #Sentiment analysis on caller content

# %%
from transformers import pipeline
sentiment_model = pipeline("sentiment-analysis", truncation=True, max_length=512, model='distilbert/distilbert-base-uncased-finetuned-sst-2-english')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
#Sentiment Analysis of Caller Data
df['sent_model']= df['CallerContent'].apply(sentiment_model)
df['Caller_Sentiment']= df['sent_model'].apply(lambda s: s[0]['label'])
df['Caller_Sentiment_Score']= df['sent_model'].apply(lambda s: s[0]['score'])
print(df[['CallerContent','Caller_Sentiment','Caller_Sentiment_Score']])
# Out:
#                                          CallerContent Caller_Sentiment  \
# 0    Hi, I just want to double check. My daughter h...         POSITIVE
# 1    last known thanks for calling corruption from ...         NEGATIVE
# 2    I'd like to speak out with the front office ab...         POSITIVE
# 3    Hi, this is Ed Jones. I'm a patient at Dr. Wil...         NEGATIVE
# 4    Hello? Yes, I'd like to make an appointment fo...         NEGATIVE
# ..                                                 ...              ...
# 181                                                            POSITIVE
# 182  You sent me to the front office. She put me on...         NEGATIVE
# 183                                                            POSITIVE
# 184  Hi, yes. I'd like to make an appointment with ...         POSITIVE
# 185  Good morning. My name is Mary Shealy, and I ne...         NEGATIVE
#
#      Caller_Sentiment_Score
# 0                  0.998999
# 1                  0.991963
# 2                  0.995155
# 3                  0.998020
# 4                  0.994520
# ..                      ...
# 181                0.748121
# 182                0.998854
# 183                0.748121
# 184                0.991734
# 185                0.996319
#
# [186 rows x 3 columns]

# %%
df.Caller_Sentiment.value_counts()
# Out:
# Caller_Sentiment
# POSITIVE    102
# NEGATIVE     84
# Name: count, dtype: int64

# %%
df.Caller_Sentiment_Score.describe()
# Out:
# count    186.000000
# mean       0.919813
# std        0.117845
# min        0.513014
# 25%        0.861991
# 50%        0.991574
# 75%        0.996564
# max        0.999823
# Name: Caller_Sentiment_Score, dtype: float64

# %%
##*Emotional analysis of caller content*##
# model= "pysentimiento/robertuito-sentiment-analysis"
model="bhadresh-savani/distilbert-base-uncased-emotion"
emotion_model = pipeline(model=model, truncation=True, max_length=512)
# Out:
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
data = ["I love you", "I hate you"]
emotion_model(data)
# Out:
# [{'label': 'love', 'score': 0.9608993530273438},
#  {'label': 'anger', 'score': 0.8268487453460693}]

# %%
df['emot_model']= df['CallerContent'].apply(emotion_model)
df['Caller_Emotion']= df['emot_model'].apply(lambda s: s[0]['label'])
df['Caller_Emotion_Score']= df['emot_model'].apply(lambda s: s[0]['score'])
print(df[['CallerContent','Caller_Emotion','Caller_Emotion_Score']])
# Out:
#                                          CallerContent Caller_Emotion  \
# 0    Hi, I just want to double check. My daughter h...            joy
# 1    last known thanks for calling corruption from ...            joy
# 2    I'd like to speak out with the front office ab...            joy
# 3    Hi, this is Ed Jones. I'm a patient at Dr. Wil...            joy
# 4    Hello? Yes, I'd like to make an appointment fo...            joy
# ..                                                 ...            ...
# 181                                                             anger
# 182  You sent me to the front office. She put me on...          anger
# 183                                                             anger
# 184  Hi, yes. I'd like to make an appointment with ...            joy
# 185  Good morning. My name is Mary Shealy, and I ne...            joy
#
#      Caller_Emotion_Score
# 0                0.998286
# 1                0.985529
# 2                0.995210
# 3                0.996436
# 4                0.913450
# ..                    ...
# 181              0.473060
# 182              0.616521
# 183              0.473060
# 184              0.996731
# 185              0.977768
#
# [186 rows x 3 columns]

# %%
df.head()
# Out:
#   Metadata       Caller                           Receiver  Timestamp  \
# 0    value        Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1    value      no_name  Crafton Family Practice (dominic) 2023-12-04
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3    value     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4    value    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
#
#                       CallContent.Seq1.CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ... call_weekday call_month  \
# 0       2023_Dec_04_13:49:32  ...       Monday   December
# 1       2023_Dec_04_14:46:53  ...       Monday   December
# 2       2023_Dec_04_15:24:59  ...       Monday   December
# 3        2023_12_04_14:59:14  ...       Monday   December
# 4        2023_12_04_14:51:12  ...       Monday   December
#
#                                        CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4  Hello? Yes, I'd like to make an appointment fo...
#
#                                      ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#                                           sent_model Caller_Sentiment  \
# 0  [{'label': 'POSITIVE', 'score': 0.998999297618...         POSITIVE
# 1  [{'label': 'NEGATIVE', 'score': 0.991962909698...         NEGATIVE
# 2  [{'label': 'POSITIVE', 'score': 0.995154619216...         POSITIVE
# 3  [{'label': 'NEGATIVE', 'score': 0.998019695281...         NEGATIVE
# 4  [{'label': 'NEGATIVE', 'score': 0.994520127773...         NEGATIVE
#
#   Caller_Sentiment_Score                                       emot_model  \
# 0               0.998999  [{'label': 'joy', 'score': 0.9982855916023254}]
# 1               0.991963  [{'label': 'joy', 'score': 0.9855291247367859}]
# 2               0.995155  [{'label': 'joy', 'score': 0.9952101111412048}]
# 3               0.998020  [{'label': 'joy', 'score': 0.9964357614517212}]
# 4               0.994520  [{'label': 'joy', 'score': 0.9134501218795776}]
#
#   Caller_Emotion Caller_Emotion_Score
# 0            joy             0.998286
# 1            joy             0.985529
# 2            joy             0.995210
# 3            joy             0.996436
# 4            joy             0.913450
#
# [5 rows x 191 columns]

# %%
df.describe()
# Out:
#                            Timestamp  Caller_Sentiment_Score  \
# count                            172              186.000000
# mean   2023-11-07 11:43:15.348837120                0.919813
# min              2023-09-20 00:00:00                0.513014
# 25%              2023-09-21 00:00:00                0.861991
# 50%              2023-09-21 00:00:00                0.991574
# 75%              2023-12-04 00:00:00                0.996564
# max              2024-10-29 00:00:00                0.999823
# std                              NaN                0.117845
#
#        Caller_Emotion_Score
# count            186.000000
# mean               0.850522
# min                0.327407
# 25%                0.768901
# 50%                0.962100
# 75%                0.995210
# max                0.998739
# std                0.199422

# %%
#Calls per weekday
df.groupby(df.call_weekday).count()
# Out:
#               Metadata  Caller  Receiver  Timestamp  \
# call_weekday
# Monday              22      26        26         26
# Thursday            64      26        66         66
# Tuesday              0       4         4          4
# Wednesday           46      76        76         76
#
#               CallContent.Seq1.CallerContent  \
# call_weekday
# Monday                                    26
# Thursday                                  10
# Tuesday                                    2
# Wednesday                                 60
#
#               CallContent.Seq1.ReceiverContent  CallContent.Seq1.Timestamp  \
# call_weekday
# Monday                                      26                          26
# Thursday                                    64                          66
# Tuesday                                      2                           2
# Wednesday                                   74                          74
#
#               CallContent.Seq2.CallerContent  \
# call_weekday
# Monday                                    26
# Thursday                                  60
# Tuesday                                    2
# Wednesday                                 70
#
#               CallContent.Seq2.ReceiverContent  CallContent.Seq2.Timestamp  \
# call_weekday
# Monday                                      26                          26
# Thursday                                    60                          66
# Tuesday                                      2                           2
# Wednesday                                   72                          74
#
#               ...  Content  call_month  CallerContent  ReceiverContent  \
# call_weekday  ...
# Monday        ...        0          26             26               26
# Thursday      ...        0          66             66               66
# Tuesday       ...        2           4              4                4
# Wednesday     ...        2          76             76               76
#
#               sent_model  Caller_Sentiment  Caller_Sentiment_Score  \
# call_weekday
# Monday                26                26                      26
# Thursday              66                66                      66
# Tuesday                4                 4                       4
# Wednesday             76                76                      76
#
#               emot_model  Caller_Emotion  Caller_Emotion_Score
# call_weekday
# Monday                26              26                    26
# Thursday              66              66                    66
# Tuesday                4               4                     4
# Wednesday             76              76                    76
#
# [4 rows x 190 columns]

# %%
df['call_weekday'].unique()
# Out:
# array(['Monday', 'Wednesday', nan, 'Thursday', 'Tuesday'], dtype=object)

# %%
df.call_weekday.value_counts()
# Out:
# call_weekday
# Wednesday    76
# Thursday     66
# Monday       26
# Tuesday       4
# Name: count, dtype: int64

# %%
df['call_month'].unique()
# Out:
# array(['December', 'November', nan, 'March', 'October', 'February',
#        'September'], dtype=object)

# %%
df.groupby(df.call_month).count()
# Out:
#             Metadata  Caller  Receiver  Timestamp  \
# call_month
# December          22      22        22         22
# February           0       2         2          2
# March              0      22        22         22
# November          20      24        24         24
# October            8      10        10         10
# September         82      52        92         92
#
#             CallContent.Seq1.CallerContent  CallContent.Seq1.ReceiverContent  \
# call_month
# December                                22                                22
# February                                 2                                 2
# March                                   20                                20
# November                                24                                24
# October                                 10                                10
# September                               20                                88
#
#             CallContent.Seq1.Timestamp  CallContent.Seq2.CallerContent  \
# call_month
# December                            22                              22
# February                             2                               2
# March                               20                              20
# November                            24                              24
# October                             10                              10
# September                           90                              80
#
#             CallContent.Seq2.ReceiverContent  CallContent.Seq2.Timestamp  ...  \
# call_month                                                                ...
# December                                  22                          22  ...
# February                                   2                           2  ...
# March                                     20                          20  ...
# November                                  24                          24  ...
# October                                   10                          10  ...
# September                                 82                          90  ...
#
#             Content  call_weekday  CallerContent  ReceiverContent  sent_model  \
# call_month
# December          0            22             22               22          22
# February          0             2              2                2           2
# March             2            22             22               22          22
# November          0            24             24               24          24
# October           0            10             10               10          10
# September         2            92             92               92          92
#
#             Caller_Sentiment  Caller_Sentiment_Score  emot_model  \
# call_month
# December                  22                      22          22
# February                   2                       2           2
# March                     22                      22          22
# November                  24                      24          24
# October                   10                      10          10
# September                 92                      92          92
#
#             Caller_Emotion  Caller_Emotion_Score
# call_month
# December                22                    22
# February                 2                     2
# March                   22                    22
# November                24                    24
# October                 10                    10
# September               92                    92
#
# [6 rows x 190 columns]

# %%
#day wise total number of calls
df_grouped = df.groupby('Timestamp')
df_grouped = df_grouped.apply(lambda x: x.groupby(pd.Grouper(key='Timestamp', freq='8H')).size())
df_grouped
# Out:
# Timestamp   Timestamp
# 2023-09-20  2023-09-20    34
# 2023-09-21  2023-09-21    58
# 2023-10-26  2023-10-26     8
# 2023-11-01  2023-11-01    18
# 2023-11-15  2023-11-15     4
# 2023-11-20  2023-11-20     2
# 2023-12-04  2023-12-04    22
# 2024-02-12  2024-02-12     2
# 2024-03-19  2024-03-19     2
# 2024-03-27  2024-03-27    20
# 2024-10-29  2024-10-29     2
# dtype: int64

# %%
# groupby timestamp in different months and count total number of calls

df_grouped_months = df.groupby(['call_month','Timestamp']).count()
df_grouped_months
# Out:
#                        Metadata  Caller  Receiver  \
# call_month Timestamp
# December   2023-12-04        22      22        22
# February   2024-02-12         0       2         2
# March      2024-03-19         0       2         2
#            2024-03-27         0      20        20
# November   2023-11-01        18      18        18
#            2023-11-15         2       4         4
#            2023-11-20         0       2         2
# October    2023-10-26         8       8         8
#            2024-10-29         0       2         2
# September  2023-09-20        26      34        34
#            2023-09-21        56      18        58
#
#                        CallContent.Seq1.CallerContent  \
# call_month Timestamp
# December   2023-12-04                              22
# February   2024-02-12                               2
# March      2024-03-19                               0
#            2024-03-27                              20
# November   2023-11-01                              18
#            2023-11-15                               4
#            2023-11-20                               2
# October    2023-10-26                               8
#            2024-10-29                               2
# September  2023-09-20                              18
#            2023-09-21                               2
#
#                        CallContent.Seq1.ReceiverContent  \
# call_month Timestamp
# December   2023-12-04                                22
# February   2024-02-12                                 2
# March      2024-03-19                                 0
#            2024-03-27                                20
# November   2023-11-01                                18
#            2023-11-15                                 4
#            2023-11-20                                 2
# October    2023-10-26                                 8
#            2024-10-29                                 2
# September  2023-09-20                                32
#            2023-09-21                                56
#
#                        CallContent.Seq1.Timestamp  \
# call_month Timestamp
# December   2023-12-04                          22
# February   2024-02-12                           2
# March      2024-03-19                           0
#            2024-03-27                          20
# November   2023-11-01                          18
#            2023-11-15                           4
#            2023-11-20                           2
# October    2023-10-26                           8
#            2024-10-29                           2
# September  2023-09-20                          32
#            2023-09-21                          58
#
#                        CallContent.Seq2.CallerContent  \
# call_month Timestamp
# December   2023-12-04                              22
# February   2024-02-12                               2
# March      2024-03-19                               0
#            2024-03-27                              20
# November   2023-11-01                              18
#            2023-11-15                               4
#            2023-11-20                               2
# October    2023-10-26                               8
#            2024-10-29                               2
# September  2023-09-20                              28
#            2023-09-21                              52
#
#                        CallContent.Seq2.ReceiverContent  \
# call_month Timestamp
# December   2023-12-04                                22
# February   2024-02-12                                 2
# March      2024-03-19                                 0
#            2024-03-27                                20
# November   2023-11-01                                18
#            2023-11-15                                 4
#            2023-11-20                                 2
# October    2023-10-26                                 8
#            2024-10-29                                 2
# September  2023-09-20                                30
#            2023-09-21                                52
#
#                        CallContent.Seq2.Timestamp  \
# call_month Timestamp
# December   2023-12-04                          22
# February   2024-02-12                           2
# March      2024-03-19                           0
#            2024-03-27                          20
# November   2023-11-01                          18
#            2023-11-15                           4
#            2023-11-20                           2
# October    2023-10-26                           8
#            2024-10-29                           2
# September  2023-09-20                          32
#            2023-09-21                          58
#
#                        CallContent.Seq3.CallerContent  ...  Content  \
# call_month Timestamp                                   ...
# December   2023-12-04                              22  ...        0
# February   2024-02-12                               2  ...        0
# March      2024-03-19                               0  ...        2
#            2024-03-27                              18  ...        0
# November   2023-11-01                              18  ...        0
#            2023-11-15                               4  ...        0
#            2023-11-20                               2  ...        0
# October    2023-10-26                               8  ...        0
#            2024-10-29                               2  ...        0
# September  2023-09-20                              18  ...        2
#            2023-09-21                              36  ...        0
#
#                        call_weekday  CallerContent  ReceiverContent  \
# call_month Timestamp
# December   2023-12-04            22             22               22
# February   2024-02-12             2              2                2
# March      2024-03-19             2              2                2
#            2024-03-27            20             20               20
# November   2023-11-01            18             18               18
#            2023-11-15             4              4                4
#            2023-11-20             2              2                2
# October    2023-10-26             8              8                8
#            2024-10-29             2              2                2
# September  2023-09-20            34             34               34
#            2023-09-21            58             58               58
#
#                        sent_model  Caller_Sentiment  Caller_Sentiment_Score  \
# call_month Timestamp
# December   2023-12-04          22                22                      22
# February   2024-02-12           2                 2                       2
# March      2024-03-19           2                 2                       2
#            2024-03-27          20                20                      20
# November   2023-11-01          18                18                      18
#            2023-11-15           4                 4                       4
#            2023-11-20           2                 2                       2
# October    2023-10-26           8                 8                       8
#            2024-10-29           2                 2                       2
# September  2023-09-20          34                34                      34
#            2023-09-21          58                58                      58
#
#                        emot_model  Caller_Emotion  Caller_Emotion_Score
# call_month Timestamp
# December   2023-12-04          22              22                    22
# February   2024-02-12           2               2                     2
# March      2024-03-19           2               2                     2
#            2024-03-27          20              20                    20
# November   2023-11-01          18              18                    18
#            2023-11-15           4               4                     4
#            2023-11-20           2               2                     2
# October    2023-10-26           8               8                     8
#            2024-10-29           2               2                     2
# September  2023-09-20          34              34                    34
#            2023-09-21          58              58                    58
#
# [11 rows x 189 columns]

# %%
df['CallContent.Seq1.Timestamp'].value_counts()
# Out:
# CallContent.Seq1.Timestamp
# 2023-09-21 00:00:00    24
# 2024-03-27 00:04:00     8
# 2023-10-26 10:04:16     6
# 2024-03-27 00:05:00     6
# 2023-11-01 14:29:05     4
#                        ..
# 2023-09-20 16:08:10     2
# 2023-09-20 15:18:51     2
# 2023-09-20 15:10:46     2
# 2023-09-20 16:08:46     2
# 2024-10-29 00:04:00     2
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# #Sentiment analysis on receiver call

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df['sent_model']= df['ReceiverContent'].apply(sentiment_model)
df['Receiver_Sentiment']= df['sent_model'].apply(lambda s: s[0]['label'])
df['Receiver_Sentiment_Score']= df['sent_model'].apply(lambda s: s[0]['score'])
print(df[['ReceiverContent','Receiver_Sentiment','Receiver_Sentiment_Score']])
# Out:
#                                        ReceiverContent Receiver_Sentiment  \
# 0    Good afternoon, this is Crafton Family Practic...           POSITIVE
# 1    is this you for the day hi I was wondering if ...           NEGATIVE
# 2    Good afternoon. Thanks for calling Grafton Fam...           POSITIVE
# 3    Good afternoon. Thanks for calling Crofton Fam...           POSITIVE
# 4    Good afternoon, this is Kumaran from Family Pr...           POSITIVE
# ..                                                 ...                ...
# 181                                                              POSITIVE
# 182  No, ma'am. It's not like that. Yes, she was on...           NEGATIVE
# 183                                                              POSITIVE
# 184  Good morning. Thanks for calling Carlson Famil...           POSITIVE
# 185  Would you like to meet the doctor in person, o...           POSITIVE
#
#      Receiver_Sentiment_Score
# 0                    0.997877
# 1                    0.980291
# 2                    0.824704
# 3                    0.996502
# 4                    0.999104
# ..                        ...
# 181                  0.748121
# 182                  0.891674
# 183                  0.748121
# 184                  0.997442
# 185                  0.992994
#
# [186 rows x 3 columns]

# %% [markdown]
# #Emotional analysis on receiver content

# %%
# model= "pysentimiento/robertuito-sentiment-analysis"
model="bhadresh-savani/distilbert-base-uncased-emotion"
emotion_model = pipeline(model=model, truncation=True, max_length=512)
emotion_model(data)
# Out:
# [{'label': 'love', 'score': 0.9608993530273438},
#  {'label': 'anger', 'score': 0.8268487453460693}]

# %%
# Emotional Analysis of Caller Data
df['emot_model']= df['ReceiverContent'].apply(emotion_model)
df['Receiver_Emotion']= df['emot_model'].apply(lambda s: s[0]['label'])
df['Receiver_Emotion_Score']= df['emot_model'].apply(lambda s: s[0]['score'])
print(df[['ReceiverContent','Receiver_Emotion','Receiver_Emotion_Score']])
# Out:
#                                        ReceiverContent Receiver_Emotion  \
# 0    Good afternoon, this is Crafton Family Practic...              joy
# 1    is this you for the day hi I was wondering if ...          sadness
# 2    Good afternoon. Thanks for calling Grafton Fam...              joy
# 3    Good afternoon. Thanks for calling Crofton Fam...              joy
# 4    Good afternoon, this is Kumaran from Family Pr...              joy
# ..                                                 ...              ...
# 181                                                               anger
# 182  No, ma'am. It's not like that. Yes, she was on...              joy
# 183                                                               anger
# 184  Good morning. Thanks for calling Carlson Famil...              joy
# 185  Would you like to meet the doctor in person, o...              joy
#
#      Receiver_Emotion_Score
# 0                  0.996388
# 1                  0.989658
# 2                  0.870192
# 3                  0.963767
# 4                  0.998083
# ..                      ...
# 181                0.473060
# 182                0.987356
# 183                0.473060
# 184                0.994273
# 185                0.913570
#
# [186 rows x 3 columns]

# %%
df.describe()
# Out:
#                            Timestamp  Caller_Sentiment_Score  \
# count                            172              186.000000
# mean   2023-11-07 11:43:15.348837120                0.919813
# min              2023-09-20 00:00:00                0.513014
# 25%              2023-09-21 00:00:00                0.861991
# 50%              2023-09-21 00:00:00                0.991574
# 75%              2023-12-04 00:00:00                0.996564
# max              2024-10-29 00:00:00                0.999823
# std                              NaN                0.117845
#
#        Caller_Emotion_Score  Receiver_Sentiment_Score  Receiver_Emotion_Score
# count            186.000000                186.000000              186.000000
# mean               0.850522                  0.934484                0.884345
# min                0.327407                  0.530524                0.356813
# 25%                0.768901                  0.937856                0.863715
# 50%                0.962100                  0.988659                0.987782
# 75%                0.995210                  0.998161                0.996786
# max                0.998739                  0.999828                0.998645
# std                0.199422                  0.108872                0.189503

# %%
df.Receiver_Emotion.value_counts()
# Out:
# Receiver_Emotion
# joy        152
# anger       18
# sadness     12
# fear         4
# Name: count, dtype: int64

# %% [markdown]
# #length of call based on word count

# %%
df.head()
# Out:
#   Metadata       Caller                           Receiver  Timestamp  \
# 0    value        Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1    value      no_name  Crafton Family Practice (dominic) 2023-12-04
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3    value     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4    value    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
#
#                       CallContent.Seq1.CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ...  \
# 0       2023_Dec_04_13:49:32  ...
# 1       2023_Dec_04_14:46:53  ...
# 2       2023_Dec_04_15:24:59  ...
# 3        2023_12_04_14:59:14  ...
# 4        2023_12_04_14:51:12  ...
#
#                                           sent_model Caller_Sentiment  \
# 0  [{'label': 'POSITIVE', 'score': 0.997876644134...         POSITIVE
# 1  [{'label': 'NEGATIVE', 'score': 0.980291128158...         NEGATIVE
# 2  [{'label': 'POSITIVE', 'score': 0.824704349040...         POSITIVE
# 3  [{'label': 'POSITIVE', 'score': 0.996501684188...         NEGATIVE
# 4  [{'label': 'POSITIVE', 'score': 0.999104082584...         NEGATIVE
#
#   Caller_Sentiment_Score                                         emot_model  \
# 0               0.998999    [{'label': 'joy', 'score': 0.9963880777359009}]
# 1               0.991963  [{'label': 'sadness', 'score': 0.9896580576896...
# 2               0.995155    [{'label': 'joy', 'score': 0.8701915144920349}]
# 3               0.998020    [{'label': 'joy', 'score': 0.9637673497200012}]
# 4               0.994520    [{'label': 'joy', 'score': 0.9980828762054443}]
#
#   Caller_Emotion Caller_Emotion_Score Receiver_Sentiment  \
# 0            joy             0.998286           POSITIVE
# 1            joy             0.985529           NEGATIVE
# 2            joy             0.995210           POSITIVE
# 3            joy             0.996436           POSITIVE
# 4            joy             0.913450           POSITIVE
#
#   Receiver_Sentiment_Score Receiver_Emotion Receiver_Emotion_Score
# 0                 0.997877              joy               0.996388
# 1                 0.980291          sadness               0.989658
# 2                 0.824704              joy               0.870192
# 3                 0.996502              joy               0.963767
# 4                 0.999104              joy               0.998083
#
# [5 rows x 195 columns]

# %%
print(df.Receiver.value_counts())
# Out:
# Receiver
# Dominic                                  62
# Kumar                                    24
# Dominic (Crofton Family Practice)        10
# Kathy                                     8
# Dominic from Crofton Family Practice      8
# Kumaran (Crofton Family Practice)         6
# Dominique                                 6
# Brandi                                    4
# Brandy                                    4
# Kathy from Crofton Family Practice        4
# Kumar from Crofton Family Practice        4
# Kathy from Crosswind Family Practice      4
# Kumar from Crawford Family Practice       2
# Dominic from Robson Family Practice       2
# No Name                                   2
# Dominic from Grobson Family Practice      2
# Dominic from Coffin Family Practice       2
# Dominic from CrossFit Family Practice     2
# Dominic from Grafton Family Practice      2
# Crafton Family Practice (Kumaran)         2
# Kathy from Proud and Family Practice      2
# Crafton Family Practice (dominic)         2
# Dominic (Crossroads Family Practice)      2
# Kumaran (Robson Family Practice)          2
# Kumaran (Carlston Family Practice)        2
# David (Crossroads Family Practice)        2
# Kumaran (Grafton Family Practice)         2
# Carole                                    2
# Name: count, dtype: int64

# %%
#length of call based on receiver content
df['ReceiverContent']
# Out:
# 0      Good afternoon, this is Crafton Family Practic...
# 1      is this you for the day hi I was wondering if ...
# 2      Good afternoon. Thanks for calling Grafton Fam...
# 3      Good afternoon. Thanks for calling Crofton Fam...
# 4      Good afternoon, this is Kumaran from Family Pr...
#                              ...
# 181
# 182    No, ma'am. It's not like that. Yes, she was on...
# 183
# 184    Good morning. Thanks for calling Carlson Famil...
# 185    Would you like to meet the doctor in person, o...
# Name: ReceiverContent, Length: 186, dtype: object

# %%
df['totalwords_receiver'] = df['ReceiverContent'].str.count(' ')
df['totalwords_receiver']
# Out:
# 0       82
# 1       58
# 2      294
# 3      143
# 4      135
#       ...
# 181      0
# 182     89
# 183      0
# 184    114
# 185    136
# Name: totalwords_receiver, Length: 186, dtype: int64

# %%
df['totalwords_receiver'].describe()
# Out:
# count    186.000000
# mean     160.860215
# std      141.902791
# min        0.000000
# 25%       76.000000
# 50%      134.000000
# 75%      195.000000
# max      816.000000
# Name: totalwords_receiver, dtype: float64

# %%
#length of call based on caller content
df['CallerContent']
# Out:
# 0      Hi, I just want to double check. My daughter h...
# 1      last known thanks for calling corruption from ...
# 2      I'd like to speak out with the front office ab...
# 3      Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4      Hello? Yes, I'd like to make an appointment fo...
#                              ...
# 181
# 182    You sent me to the front office. She put me on...
# 183
# 184    Hi, yes. I'd like to make an appointment with ...
# 185    Good morning. My name is Mary Shealy, and I ne...
# Name: CallerContent, Length: 186, dtype: object

# %%
df['totalwords_caller'] = df['CallerContent'].str.count(' ')
df['totalwords_caller'].describe()
# Out:
# count    186.000000
# mean     111.043011
# std       83.701647
# min        0.000000
# 25%       50.000000
# 50%       91.000000
# 75%      161.000000
# max      341.000000
# Name: totalwords_caller, dtype: float64

# %%
##Sentiment by person making the call
df.Caller_Emotion.value_counts()
# Out:
# Caller_Emotion
# joy         124
# anger        36
# sadness      20
# fear          2
# surprise      2
# love          2
# Name: count, dtype: int64

# %%
df_n =df[df['Caller_Emotion']=='anger']['Caller']

# %%
df_n.value_counts()
# Out:
# Caller
# No name          6
# Marilyn Hardy    6
# Dale Carnett     2
# Unnamed          2
# Dr. Williams     2
# Judith           2
# Name: count, dtype: int64

# %%
df[df['Caller_Emotion']=='sadness']['Caller']
# Out:
# 14             Robert
# 15       McKay Godwin
# 20      Cheryl Naiman
# 23             Brandy
# 33            No Name
# 34              Randy
# 55            Unknown
# 70             Judith
# 76             Latoya
# 79     William Taylor
# 107            Robert
# 108      McKay Godwin
# 113     Cheryl Naiman
# 116            Brandy
# 126           No Name
# 127             Randy
# 148           Unknown
# 163            Judith
# 169            Latoya
# 172    William Taylor
# Name: Caller, dtype: object

# %%
print(df[df['Caller_Emotion']=='sadness']['Caller'].value_counts())
# Out:
# Caller
# Robert            2
# McKay Godwin      2
# Cheryl Naiman     2
# Brandy            2
# No Name           2
# Randy             2
# Unknown           2
# Judith            2
# Latoya            2
# William Taylor    2
# Name: count, dtype: int64

# %%
df[df['Receiver_Emotion']=='fear']['Receiver'].value_counts()
# Out:
# Receiver
# Dominique                               2
# Dominic from Grafton Family Practice    2
# Name: count, dtype: int64

# %%
df.columns.to_list()
# Out:
# ['Metadata',
#  'Caller',
#  'Receiver',
#  'Timestamp',
#  'CallContent.Seq1.CallerContent',
#  'CallContent.Seq1.ReceiverContent',
#  'CallContent.Seq1.Timestamp',
#  'CallContent.Seq2.CallerContent',
#  'CallContent.Seq2.ReceiverContent',
#  'CallContent.Seq2.Timestamp',
#  'CallContent.Seq3.CallerContent',
#  'CallContent.Seq3.ReceiverContent',
#  'CallContent.Seq3.Timestamp',
#  'CallContent.Seq4.CallerContent',
#  'CallContent.Seq4.ReceiverContent',
#  'CallContent.Seq4.Timestamp',
#  'CallContent.Seq5.CallerContent',
#  'CallContent.Seq5.ReceiverContent',
#  'CallContent.Seq5.Timestamp',
#  'CallContent.Seq6.CallerContent',
#  'CallContent.Seq6.ReceiverContent',
#  'CallContent.Seq6.Timestamp',
#  'CallContent.Seq7.CallerContent',
#  'CallContent.Seq7.ReceiverContent',
#  'CallContent.Seq7.Timestamp',
#  'CallContent.Seq8.CallerContent',
#  'CallContent.Seq8.ReceiverContent',
#  'CallContent.Seq8.Timestamp',
#  'CallContent.Seq9.CallerContent',
#  'CallContent.Seq9.ReceiverContent',
#  'CallContent.Seq9.Timestamp',
#  'CallContent.Seq10.CallerContent',
#  'CallContent.Seq10.ReceiverContent',
#  'CallContent.Seq10.Timestamp',
#  'CallContent.Seq11.CallerContent',
#  'CallContent.Seq11.ReceiverContent',
#  'CallContent.Seq11.Timestamp',
#  'CallContent.Seq12.CallerContent',
#  'CallContent.Seq12.ReceiverContent',
#  'CallContent.Seq12.Timestamp',
#  'CallContent.Seq13.CallerContent',
#  'CallContent.Seq13.ReceiverContent',
#  'CallContent.Seq13.Timestamp',
#  'CallContent.Seq14.CallerContent',
#  'CallContent.Seq14.ReceiverContent',
#  'CallContent.Seq14.Timestamp',
#  'CallContent.Seq15.CallerContent',
#  'CallContent.Seq15.ReceiverContent',
#  'CallContent.Seq15.Timestamp',
#  'CallContent.Seq16.CallerContent',
#  'CallContent.Seq16.ReceiverContent',
#  'CallContent.Seq16.Timestamp',
#  'Conversation.Participants',
#  'Conversation.Messages',
#  'CallContent.Seq2.OtherSpeakerContent',
#  'CallContent.Seq6.OtherSpeakerContent',
#  'CallContent.Seq7.OtherSpeakerContent',
#  'CallContent.Seq12.OtherSpeakerContent',
#  'CallContent.Seq14.OtherSpeakerContent',
#  'CallContent.Seq15.OtherSpeakerContent',
#  'CallContent.Seq17.CallerContent',
#  'CallContent.Seq17.ReceiverContent',
#  'CallContent.Seq17.Timestamp',
#  'CallContent.Seq18.CallerContent',
#  'CallContent.Seq18.ReceiverContent',
#  'CallContent.Seq18.Timestamp',
#  'CallContent.Seq19.CallerContent',
#  'CallContent.Seq19.ReceiverContent',
#  'CallContent.Seq19.Timestamp',
#  'CallContent.Seq20.CallerContent',
#  'CallContent.Seq20.ReceiverContent',
#  'CallContent.Seq20.Timestamp',
#  'CallContent.Seq21.OtherSpeakerContent',
#  'CallContent.Seq21.Timestamp',
#  'CallContent.Seq22.CallerContent',
#  'CallContent.Seq22.ReceiverContent',
#  'CallContent.Seq22.Timestamp',
#  'CallContent.Seq23.CallerContent',
#  'CallContent.Seq23.ReceiverContent',
#  'CallContent.Seq23.Timestamp',
#  'CallContent.Seq24.CallerContent',
#  'CallContent.Seq24.ReceiverContent',
#  'CallContent.Seq24.Timestamp',
#  'CallContent.Seq25.CallerContent',
#  'CallContent.Seq25.Timestamp',
#  'CallContent.Seq21.ReceiverContent',
#  'CallContent.Seq25.ReceiverContent',
#  'CallContent.Seq26.ReceiverContent',
#  'CallContent.Seq26.Timestamp',
#  'CallContent.Seq27.CallerContent',
#  'CallContent.Seq27.ReceiverContent',
#  'CallContent.Seq27.Timestamp',
#  'CallContent.Seq28.CallerContent',
#  'CallContent.Seq28.ReceiverContent',
#  'CallContent.Seq28.Timestamp',
#  'CallContent.Seq29.CallerContent',
#  'CallContent.Seq29.ReceiverContent',
#  'CallContent.Seq29.Timestamp',
#  'CallContent.Seq30.CallerContent',
#  'CallContent.Seq30.ReceiverContent',
#  'CallContent.Seq30.Timestamp',
#  'CallContent.Seq31.CallerContent',
#  'CallContent.Seq31.ReceiverContent',
#  'CallContent.Seq31.Timestamp',
#  'CallContent.Seq32.CallerContent',
#  'CallContent.Seq32.ReceiverContent',
#  'CallContent.Seq32.Timestamp',
#  'CallContent.Seq33.ReceiverContent',
#  'CallContent.Seq33.Timestamp',
#  'CallContent.Seq34.CallerContent',
#  'CallContent.Seq34.ReceiverContent',
#  'CallContent.Seq34.Timestamp',
#  'CallContent.Seq35.CallerContent',
#  'CallContent.Seq35.ReceiverContent',
#  'CallContent.Seq35.Timestamp',
#  'CallContent.Seq36.CallerContent',
#  'CallContent.Seq36.ReceiverContent',
#  'CallContent.Seq36.Timestamp',
#  'CallContent.Seq21.CallerContent',
#  'CallContent.Seq4.BrandiContent',
#  'CallContent.Seq10.OtherSpeakerContent',
#  'CallContent.Seq17.OtherSpeakerContent',
#  'CallContent.Seq19.OtherSpeakerContent',
#  'CallContent.Seq20.OtherSpeakerContent',
#  'CallContent.Seq22.OtherSpeakerContent',
#  'CallContent.Seq23.OtherSpeakerContent',
#  'CallContent.Seq24.OtherSpeakerContent',
#  'CallContent.Seq25.OtherSpeakerContent',
#  'CallContent.Seq26.CallerContent',
#  'CallContent.Seq1.OtherSpeakerContent',
#  'CallContent.Seq8.OtherSpeakerContent',
#  'CallContent.Seq9.OtherSpeakerContent',
#  'OtherSpeaker.Content',
#  'OtherSpeaker.Timestamp',
#  'CallContent.Seq3.OtherSpeakerContent',
#  'CallContent.Seq4.SpeakerContent',
#  'CallContent.Seq37.ReceiverContent',
#  'CallContent.Seq37.Timestamp',
#  'CallContent.Seq38.CallerContent',
#  'CallContent.Seq38.ReceiverContent',
#  'CallContent.Seq38.Timestamp',
#  'CallContent.Seq39.ReceiverContent',
#  'CallContent.Seq39.Timestamp',
#  'CallContent.Seq40.CallerContent',
#  'CallContent.Seq40.ReceiverContent',
#  'CallContent.Seq40.Timestamp',
#  'CallContent.Seq41.ReceiverContent',
#  'CallContent.Seq41.Timestamp',
#  'CallContent.Seq42.ReceiverContent',
#  'CallContent.Seq42.Timestamp',
#  'CallContent.Seq43.CallerContent',
#  'CallContent.Seq43.ReceiverContent',
#  'CallContent.Seq43.Timestamp',
#  'CallContent.Seq44.ReceiverContent',
#  'CallContent.Seq44.Timestamp',
#  'CallContent.Seq45.ReceiverContent',
#  'CallContent.Seq45.Timestamp',
#  'CallContent.Seq46.ReceiverContent',
#  'CallContent.Seq46.Timestamp',
#  'CallContent.Seq47.ReceiverContent',
#  'CallContent.Seq47.Timestamp',
#  'CallContent.Seq48.ReceiverContent',
#  'CallContent.Seq48.Timestamp',
#  'CallContent.Seq49.CallerContent',
#  'CallContent.Seq49.ReceiverContent',
#  'CallContent.Seq49.Timestamp',
#  'CallContent.Seq50.ReceiverContent',
#  'CallContent.Seq50.Timestamp',
#  'CallContent.Seq51.CallerContent',
#  'CallContent.Seq51.ReceiverContent',
#  'CallContent.Seq51.Timestamp',
#  'CallContent.Seq52.ReceiverContent',
#  'CallContent.Seq52.Timestamp',
#  'CallContent.Seq53.ReceiverContent',
#  'CallContent.Seq53.Timestamp',
#  'CallContent.Seq54.CallerContent',
#  'CallContent.Seq54.ReceiverContent',
#  'CallContent.Seq54.Timestamp',
#  'CallContent.Seq11.OtherSpeakerContent',
#  'CallContent.Seq5.OtherSpeakerContent',
#  'Content',
#  'call_weekday',
#  'call_month',
#  'CallerContent',
#  'ReceiverContent',
#  'sent_model',
#  'Caller_Sentiment',
#  'Caller_Sentiment_Score',
#  'emot_model',
#  'Caller_Emotion',
#  'Caller_Emotion_Score',
#  'Receiver_Sentiment',
#  'Receiver_Sentiment_Score',
#  'Receiver_Emotion',
#  'Receiver_Emotion_Score',
#  'totalwords_receiver',
#  'totalwords_caller']

# %% [markdown]
# ##Counting most frequent words in caller and receiver content

# %%
from collections import Counter
receiver_content_words = []
for content in df['ReceiverContent']:
  receiver_content_words.extend(content.split())

receiver_content_word_counts = Counter(receiver_content_words)

most_common_words = receiver_content_word_counts.most_common(10)

print("Most common words in receiver content:")
for word, count in most_common_words:
  print(f"{word}: {count}")
# Out:
# Most common words in receiver content:
# you: 1188
# I: 810
# the: 808
# to: 766
# a: 644
# for: 582
# and: 530
# me: 446
# is: 424
# have: 390

# %%
import gensim
from gensim.parsing.preprocessing import preprocess_documents

# Remove stopwords from receiver_content using gensim
receiver_content_without_stopwords = []
for content in df['ReceiverContent']:
    processed_content = preprocess_documents([content])
    receiver_content_without_stopwords.append(processed_content[0])

# Determine the most common words
receiver_content_word_counts = Counter(word for content in receiver_content_without_stopwords for word in content)
most_common_words = receiver_content_word_counts.most_common(30)

print("Most common words in receiver content without stopwords:")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# Most common words in receiver content without stopwords:
# okai: 482
# thank: 342
# let: 312
# ye: 242
# dai: 232
# practic: 204
# bye: 198
# famili: 196
# call: 196
# good: 190
# yeah: 176
# appoint: 162
# transfer: 162
# todai: 160
# help: 150
# great: 136
# like: 128
# know: 120
# sir: 120
# right: 118
# assist: 102
# sure: 102
# moment: 100
# onlin: 100
# go: 100
# kindli: 98
# correct: 96
# stai: 92
# crofton: 90
# leav: 90

# %%
# Remove stopwords from Caller using gensim
caller_content_without_stopwords = []
for content in df['CallerContent']:
    processed_content = preprocess_documents([content])
    caller_content_without_stopwords.append(processed_content[0])

# Determine the most common words
caller_content_word_counts = Counter(word for content in caller_content_without_stopwords for word in content)
most_common_words = caller_content_word_counts.most_common(30)

print("Most common words in receiver content without stopwords:")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# Most common words in receiver content without stopwords:
# okai: 292
# thank: 246
# ye: 206
# yeah: 176
# bye: 142
# right: 134
# need: 130
# appoint: 126
# like: 110
# call: 108
# william: 106
# good: 96
# want: 94
# know: 84
# patient: 68
# morn: 68
# work: 64
# offic: 58
# go: 58
# todai: 58
# sure: 56
# brandi: 56
# dai: 56
# let: 54
# email: 52
# time: 50
# talk: 48
# prescript: 46
# blood: 46
# sir: 44

# %% [markdown]
# ##length of call

# %%
df.head()
# Out:
#   Metadata       Caller                           Receiver  Timestamp  \
# 0    value        Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1    value      no_name  Crafton Family Practice (dominic) 2023-12-04
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3    value     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4    value    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
#
#                       CallContent.Seq1.CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ... Caller_Sentiment_Score  \
# 0       2023_Dec_04_13:49:32  ...               0.998999
# 1       2023_Dec_04_14:46:53  ...               0.991963
# 2       2023_Dec_04_15:24:59  ...               0.995155
# 3        2023_12_04_14:59:14  ...               0.998020
# 4        2023_12_04_14:51:12  ...               0.994520
#
#                                           emot_model Caller_Emotion  \
# 0    [{'label': 'joy', 'score': 0.9963880777359009}]            joy
# 1  [{'label': 'sadness', 'score': 0.9896580576896...            joy
# 2    [{'label': 'joy', 'score': 0.8701915144920349}]            joy
# 3    [{'label': 'joy', 'score': 0.9637673497200012}]            joy
# 4    [{'label': 'joy', 'score': 0.9980828762054443}]            joy
#
#   Caller_Emotion_Score Receiver_Sentiment Receiver_Sentiment_Score  \
# 0             0.998286           POSITIVE                 0.997877
# 1             0.985529           NEGATIVE                 0.980291
# 2             0.995210           POSITIVE                 0.824704
# 3             0.996436           POSITIVE                 0.996502
# 4             0.913450           POSITIVE                 0.999104
#
#   Receiver_Emotion Receiver_Emotion_Score totalwords_receiver  \
# 0              joy               0.996388                  82
# 1          sadness               0.989658                  58
# 2              joy               0.870192                 294
# 3              joy               0.963767                 143
# 4              joy               0.998083                 135
#
#   totalwords_caller
# 0                65
# 1                44
# 2                85
# 3               152
# 4                88
#
# [5 rows x 197 columns]

# %%
good_file
# Out:
# [PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_13_49_18.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_46_53.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_24_59.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_59_14.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_51_12.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_37_27.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_37_08.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_25_39.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_08_50_15.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_16_07_23.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_16_00_34.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_23_00.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_03_03.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_03_16.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_13_37_46_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_03_36.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_35_20.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_35_32.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_17_16.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_43_44.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_07_15_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_26_09_06_05_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_15_18_05_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_15_00_48_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_12_22_11_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_13_36_46_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_26_09_05_48_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_15_25.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_18_35_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_19_24_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_20_27_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_04_25_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_35_17_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_14_36_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_31_24_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_06_17_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_13_31_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_14_12_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_08_10_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_18_51_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_10_46_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_08_46_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_21_05_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_sep_20_15_29_16_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_03_09_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_10_50_jsofile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_24_47_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_08_58_16_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_19_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_03_05_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_08_40_55_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_05_10_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_18_00_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_13_18_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_59_17_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_05_14_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_28_56_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_01_33_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_08_36_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_18_26_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_28_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_13_22_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_39_01_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_45_53_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_12_17_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_12_29_57_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_18_37_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_15_29_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_58_40_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_56_44_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_32_00_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_01_21_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_50_56_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_30_02_jssonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_03_24_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_28_29_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_33_19_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_58_36_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_08_53_45_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_08_50_21_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_19_19_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_39_00_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_14_54_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_40_22_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_18_04_timestamped (1).json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_16_02_14_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_01_16_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_06_25_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_11_00_06_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_06_25_timestamoped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_18_04_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/timestamp20231026100416.json'),
#  PosixPath('/content/drive/MyDrive/json_115/timestamped_2023_Oct_25_11_52_34_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_13_49_18.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_46_53.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_24_59.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_59_14.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_14_51_12.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_37_27.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_37_08.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_15_25_39.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_08_50_15.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_16_07_23.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Dec_04_16_00_34.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_23_00.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_03_03.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_03_16.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_13_37_46_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_03_36.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_35_20.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_35_32.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_17_16.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_09_43_44.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_07_15_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_26_09_06_05_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_15_18_05_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_15_00_48_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_12_22_11_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_25_13_36_46_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_26_09_05_48_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Nov_01_10_15_25.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_18_35_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_19_24_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_20_27_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_04_25_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_35_17_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_14_36_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_09_31_24_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_10_06_17_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_13_31_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_14_12_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_08_10_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_18_51_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_10_46_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_08_46_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_15_21_05_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_sep_20_15_29_16_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_03_09_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_10_50_jsofile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_24_47_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_08_58_16_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_20_16_19_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_03_05_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Oct_30_08_40_55_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_05_10_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_18_00_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_13_18_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_09_59_17_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_05_14_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_28_56_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_01_33_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_08_36_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_18_26_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_28_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_10_13_22_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_39_01_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_45_53_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_12_17_49_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_12_29_57_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_18_37_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_11_15_29_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_58_40_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_56_44_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_32_00_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_01_21_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_50_56_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_30_02_jssonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_03_24_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_28_29_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_33_19_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_13_58_36_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_08_53_45_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_08_50_21_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_19_19_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_14_39_00_jsonfile.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_14_54_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_15_40_22_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_18_04_timestamped (1).json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_21_16_02_14_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_01_16_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_06_25_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_11_00_06_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_06_25_timestamoped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/crhg_2023_Sep_22_09_18_04_timestamped.json'),
#  PosixPath('/content/drive/MyDrive/json_115/timestamp20231026100416.json'),
#  PosixPath('/content/drive/MyDrive/json_115/timestamped_2023_Oct_25_11_52_34_timestamped.json')]

# %%
df.columns.to_list()
# Out:
# ['Metadata',
#  'Caller',
#  'Receiver',
#  'Timestamp',
#  'CallContent.Seq1.CallerContent',
#  'CallContent.Seq1.ReceiverContent',
#  'CallContent.Seq1.Timestamp',
#  'CallContent.Seq2.CallerContent',
#  'CallContent.Seq2.ReceiverContent',
#  'CallContent.Seq2.Timestamp',
#  'CallContent.Seq3.CallerContent',
#  'CallContent.Seq3.ReceiverContent',
#  'CallContent.Seq3.Timestamp',
#  'CallContent.Seq4.CallerContent',
#  'CallContent.Seq4.ReceiverContent',
#  'CallContent.Seq4.Timestamp',
#  'CallContent.Seq5.CallerContent',
#  'CallContent.Seq5.ReceiverContent',
#  'CallContent.Seq5.Timestamp',
#  'CallContent.Seq6.CallerContent',
#  'CallContent.Seq6.ReceiverContent',
#  'CallContent.Seq6.Timestamp',
#  'CallContent.Seq7.CallerContent',
#  'CallContent.Seq7.ReceiverContent',
#  'CallContent.Seq7.Timestamp',
#  'CallContent.Seq8.CallerContent',
#  'CallContent.Seq8.ReceiverContent',
#  'CallContent.Seq8.Timestamp',
#  'CallContent.Seq9.CallerContent',
#  'CallContent.Seq9.ReceiverContent',
#  'CallContent.Seq9.Timestamp',
#  'CallContent.Seq10.CallerContent',
#  'CallContent.Seq10.ReceiverContent',
#  'CallContent.Seq10.Timestamp',
#  'CallContent.Seq11.CallerContent',
#  'CallContent.Seq11.ReceiverContent',
#  'CallContent.Seq11.Timestamp',
#  'CallContent.Seq12.CallerContent',
#  'CallContent.Seq12.ReceiverContent',
#  'CallContent.Seq12.Timestamp',
#  'CallContent.Seq13.CallerContent',
#  'CallContent.Seq13.ReceiverContent',
#  'CallContent.Seq13.Timestamp',
#  'CallContent.Seq14.CallerContent',
#  'CallContent.Seq14.ReceiverContent',
#  'CallContent.Seq14.Timestamp',
#  'CallContent.Seq15.CallerContent',
#  'CallContent.Seq15.ReceiverContent',
#  'CallContent.Seq15.Timestamp',
#  'CallContent.Seq16.CallerContent',
#  'CallContent.Seq16.ReceiverContent',
#  'CallContent.Seq16.Timestamp',
#  'Conversation.Participants',
#  'Conversation.Messages',
#  'CallContent.Seq2.OtherSpeakerContent',
#  'CallContent.Seq6.OtherSpeakerContent',
#  'CallContent.Seq7.OtherSpeakerContent',
#  'CallContent.Seq12.OtherSpeakerContent',
#  'CallContent.Seq14.OtherSpeakerContent',
#  'CallContent.Seq15.OtherSpeakerContent',
#  'CallContent.Seq17.CallerContent',
#  'CallContent.Seq17.ReceiverContent',
#  'CallContent.Seq17.Timestamp',
#  'CallContent.Seq18.CallerContent',
#  'CallContent.Seq18.ReceiverContent',
#  'CallContent.Seq18.Timestamp',
#  'CallContent.Seq19.CallerContent',
#  'CallContent.Seq19.ReceiverContent',
#  'CallContent.Seq19.Timestamp',
#  'CallContent.Seq20.CallerContent',
#  'CallContent.Seq20.ReceiverContent',
#  'CallContent.Seq20.Timestamp',
#  'CallContent.Seq21.OtherSpeakerContent',
#  'CallContent.Seq21.Timestamp',
#  'CallContent.Seq22.CallerContent',
#  'CallContent.Seq22.ReceiverContent',
#  'CallContent.Seq22.Timestamp',
#  'CallContent.Seq23.CallerContent',
#  'CallContent.Seq23.ReceiverContent',
#  'CallContent.Seq23.Timestamp',
#  'CallContent.Seq24.CallerContent',
#  'CallContent.Seq24.ReceiverContent',
#  'CallContent.Seq24.Timestamp',
#  'CallContent.Seq25.CallerContent',
#  'CallContent.Seq25.Timestamp',
#  'CallContent.Seq21.ReceiverContent',
#  'CallContent.Seq25.ReceiverContent',
#  'CallContent.Seq26.ReceiverContent',
#  'CallContent.Seq26.Timestamp',
#  'CallContent.Seq27.CallerContent',
#  'CallContent.Seq27.ReceiverContent',
#  'CallContent.Seq27.Timestamp',
#  'CallContent.Seq28.CallerContent',
#  'CallContent.Seq28.ReceiverContent',
#  'CallContent.Seq28.Timestamp',
#  'CallContent.Seq29.CallerContent',
#  'CallContent.Seq29.ReceiverContent',
#  'CallContent.Seq29.Timestamp',
#  'CallContent.Seq30.CallerContent',
#  'CallContent.Seq30.ReceiverContent',
#  'CallContent.Seq30.Timestamp',
#  'CallContent.Seq31.CallerContent',
#  'CallContent.Seq31.ReceiverContent',
#  'CallContent.Seq31.Timestamp',
#  'CallContent.Seq32.CallerContent',
#  'CallContent.Seq32.ReceiverContent',
#  'CallContent.Seq32.Timestamp',
#  'CallContent.Seq33.ReceiverContent',
#  'CallContent.Seq33.Timestamp',
#  'CallContent.Seq34.CallerContent',
#  'CallContent.Seq34.ReceiverContent',
#  'CallContent.Seq34.Timestamp',
#  'CallContent.Seq35.CallerContent',
#  'CallContent.Seq35.ReceiverContent',
#  'CallContent.Seq35.Timestamp',
#  'CallContent.Seq36.CallerContent',
#  'CallContent.Seq36.ReceiverContent',
#  'CallContent.Seq36.Timestamp',
#  'CallContent.Seq21.CallerContent',
#  'CallContent.Seq4.BrandiContent',
#  'CallContent.Seq10.OtherSpeakerContent',
#  'CallContent.Seq17.OtherSpeakerContent',
#  'CallContent.Seq19.OtherSpeakerContent',
#  'CallContent.Seq20.OtherSpeakerContent',
#  'CallContent.Seq22.OtherSpeakerContent',
#  'CallContent.Seq23.OtherSpeakerContent',
#  'CallContent.Seq24.OtherSpeakerContent',
#  'CallContent.Seq25.OtherSpeakerContent',
#  'CallContent.Seq26.CallerContent',
#  'CallContent.Seq1.OtherSpeakerContent',
#  'CallContent.Seq8.OtherSpeakerContent',
#  'CallContent.Seq9.OtherSpeakerContent',
#  'OtherSpeaker.Content',
#  'OtherSpeaker.Timestamp',
#  'CallContent.Seq3.OtherSpeakerContent',
#  'CallContent.Seq4.SpeakerContent',
#  'CallContent.Seq37.ReceiverContent',
#  'CallContent.Seq37.Timestamp',
#  'CallContent.Seq38.CallerContent',
#  'CallContent.Seq38.ReceiverContent',
#  'CallContent.Seq38.Timestamp',
#  'CallContent.Seq39.ReceiverContent',
#  'CallContent.Seq39.Timestamp',
#  'CallContent.Seq40.CallerContent',
#  'CallContent.Seq40.ReceiverContent',
#  'CallContent.Seq40.Timestamp',
#  'CallContent.Seq41.ReceiverContent',
#  'CallContent.Seq41.Timestamp',
#  'CallContent.Seq42.ReceiverContent',
#  'CallContent.Seq42.Timestamp',
#  'CallContent.Seq43.CallerContent',
#  'CallContent.Seq43.ReceiverContent',
#  'CallContent.Seq43.Timestamp',
#  'CallContent.Seq44.ReceiverContent',
#  'CallContent.Seq44.Timestamp',
#  'CallContent.Seq45.ReceiverContent',
#  'CallContent.Seq45.Timestamp',
#  'CallContent.Seq46.ReceiverContent',
#  'CallContent.Seq46.Timestamp',
#  'CallContent.Seq47.ReceiverContent',
#  'CallContent.Seq47.Timestamp',
#  'CallContent.Seq48.ReceiverContent',
#  'CallContent.Seq48.Timestamp',
#  'CallContent.Seq49.CallerContent',
#  'CallContent.Seq49.ReceiverContent',
#  'CallContent.Seq49.Timestamp',
#  'CallContent.Seq50.ReceiverContent',
#  'CallContent.Seq50.Timestamp',
#  'CallContent.Seq51.CallerContent',
#  'CallContent.Seq51.ReceiverContent',
#  'CallContent.Seq51.Timestamp',
#  'CallContent.Seq52.ReceiverContent',
#  'CallContent.Seq52.Timestamp',
#  'CallContent.Seq53.ReceiverContent',
#  'CallContent.Seq53.Timestamp',
#  'CallContent.Seq54.CallerContent',
#  'CallContent.Seq54.ReceiverContent',
#  'CallContent.Seq54.Timestamp',
#  'CallContent.Seq11.OtherSpeakerContent',
#  'CallContent.Seq5.OtherSpeakerContent',
#  'Content',
#  'call_weekday',
#  'call_month',
#  'CallerContent',
#  'ReceiverContent',
#  'sent_model',
#  'Caller_Sentiment',
#  'Caller_Sentiment_Score',
#  'emot_model',
#  'Caller_Emotion',
#  'Caller_Emotion_Score',
#  'Receiver_Sentiment',
#  'Receiver_Sentiment_Score',
#  'Receiver_Emotion',
#  'Receiver_Emotion_Score',
#  'totalwords_receiver',
#  'totalwords_caller']

# %%
df_n2 = df
df_n2
# Out:
#     Metadata         Caller                           Receiver  Timestamp  \
# 0      value          Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1      value        no_name  Crafton Family Practice (dominic) 2023-12-04
# 2      value    Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3      value       Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4      value      Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
# ..       ...            ...                                ...        ...
# 181      NaN        No name                            Dominic        NaT
# 182      NaN  Marilyn Hardy                            Dominic 2023-09-20
# 183      NaN        No name                            Dominic        NaT
# 184    value        Allison                              Kumar 2023-10-26
# 185      NaN    Mary Shealy                             Carole 2024-10-29
#
#                         CallContent.Seq1.CallerContent  \
# 0    Hi, I just want to double check. My daughter h...
# 1    last known thanks for calling corruption from ...
# 2    I'd like to speak out with the front office ab...
# 3    Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                               Hello?
# ..                                                 ...
# 181                                                NaN
# 182  You sent me to the front office. She put me on...
# 183                                                NaN
# 184  Hi, yes. I'd like to make an appointment with ...
# 185  Good morning. My name is Mary Shealy, and I ne...
#
#                       CallContent.Seq1.ReceiverContent  \
# 0    Good afternoon, this is Crafton Family Practic...
# 1    is this you for the day hi I was wondering if ...
# 2    Good afternoon. Thanks for calling Grafton Fam...
# 3    Good afternoon. Thanks for calling Crofton Fam...
# 4    Good afternoon, this is Kumaran from Family Pr...
# ..                                                 ...
# 181                                                NaN
# 182  No, ma'am. It's not like that. Yes, she was on...
# 183                                                NaN
# 184  Good morning. Thanks for calling Carlson Famil...
# 185  Would you like to meet the doctor in person, o...
#
#     CallContent.Seq1.Timestamp  \
# 0         2023_Dec_04_13:49:18
# 1         2023_Dec_04_14:46:53
# 2         2023_Dec_04_15:24:59
# 3          2023_12_04_14:59:14
# 4          2023_12_04_14:51:12
# ..                         ...
# 181                        NaN
# 182        2023-09-20 10:03:04
# 183                        NaN
# 184        2023-10-26 10:04:16
# 185        2024-10-29 00:04:00
#
#                         CallContent.Seq2.CallerContent  \
# 0                             Sure, January 1st, 1997.
# 1    pardon me yeah can you give me a minute let me...
# 2                                     Okay, thank you.
# 3                                     Okay. Thank you.
# 4    Yes, I'd like to make an appointment for follo...
# ..                                                 ...
# 181                                                NaN
# 182  Who am I speaking with? I'm calling because Br...
# 183                                                NaN
# 184                         A televisit would be fine.
# 185                        I'd rather do it in person.
#
#                       CallContent.Seq2.ReceiverContent  \
# 0    Yeah, sure. Could I take the patient's date of...
# 1    sure I'm sorry yeah I'm really sorry mom all t...
# 2    Okay, one moment. Let me shout for you to the ...
# 3    Sure. Regarding that, I need to transfer you t...
# 4    Sure. Would you like to meet the doctor in per...
# ..                                                 ...
# 181                                                NaN
# 182  Okay. Let me see what's going on. I'll try to ...
# 183                                                NaN
# 184  Would you like to meet the doctor in person or...
# 185              Okay, one moment. Let me check on it.
#
#     CallContent.Seq2.Timestamp  ... Caller_Sentiment_Score  \
# 0         2023_Dec_04_13:49:32  ...               0.998999
# 1         2023_Dec_04_14:46:53  ...               0.991963
# 2         2023_Dec_04_15:24:59  ...               0.995155
# 3          2023_12_04_14:59:14  ...               0.998020
# 4          2023_12_04_14:51:12  ...               0.994520
# ..                         ...  ...                    ...
# 181                        NaN  ...               0.748121
# 182        2023-09-20 10:03:45  ...               0.998854
# 183                        NaN  ...               0.748121
# 184        2023-10-26 10:04:25  ...               0.991734
# 185        2024-10-29 00:16:00  ...               0.996319
#
#                                             emot_model Caller_Emotion  \
# 0      [{'label': 'joy', 'score': 0.9963880777359009}]            joy
# 1    [{'label': 'sadness', 'score': 0.9896580576896...            joy
# 2      [{'label': 'joy', 'score': 0.8701915144920349}]            joy
# 3      [{'label': 'joy', 'score': 0.9637673497200012}]            joy
# 4      [{'label': 'joy', 'score': 0.9980828762054443}]            joy
# ..                                                 ...            ...
# 181  [{'label': 'anger', 'score': 0.4730597138404846}]          anger
# 182     [{'label': 'joy', 'score': 0.987355649471283}]          anger
# 183  [{'label': 'anger', 'score': 0.4730597138404846}]          anger
# 184     [{'label': 'joy', 'score': 0.994272768497467}]            joy
# 185     [{'label': 'joy', 'score': 0.913569986820221}]            joy
#
#     Caller_Emotion_Score Receiver_Sentiment Receiver_Sentiment_Score  \
# 0               0.998286           POSITIVE                 0.997877
# 1               0.985529           NEGATIVE                 0.980291
# 2               0.995210           POSITIVE                 0.824704
# 3               0.996436           POSITIVE                 0.996502
# 4               0.913450           POSITIVE                 0.999104
# ..                   ...                ...                      ...
# 181             0.473060           POSITIVE                 0.748121
# 182             0.616521           NEGATIVE                 0.891674
# 183             0.473060           POSITIVE                 0.748121
# 184             0.996731           POSITIVE                 0.997442
# 185             0.977768           POSITIVE                 0.992994
#
#     Receiver_Emotion Receiver_Emotion_Score totalwords_receiver  \
# 0                joy               0.996388                  82
# 1            sadness               0.989658                  58
# 2                joy               0.870192                 294
# 3                joy               0.963767                 143
# 4                joy               0.998083                 135
# ..               ...                    ...                 ...
# 181            anger               0.473060                   0
# 182              joy               0.987356                  89
# 183            anger               0.473060                   0
# 184              joy               0.994273                 114
# 185              joy               0.913570                 136
#
#     totalwords_caller
# 0                  65
# 1                  44
# 2                  85
# 3                 152
# 4                  88
# ..                ...
# 181                 0
# 182                91
# 183                 0
# 184                49
# 185               112
#
# [186 rows x 197 columns]

# %%
import pandas as pd

def parse_timestamp(timestamp_str):
    formats = [
        '%Y_%b_%d_%H:%M:%S',
        '%Y_%m_%d_%H:%M:%S',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%b-%d %H:%M:%S','%Y-%m-%d'
    ]
    for fmt in formats:
        try:
            return pd.to_datetime(timestamp_str, format=fmt)
        except ValueError:
            pass
    raise ValueError(f"Failed to parse timestamp: {timestamp_str}")

delta_list = []
for i in range(1, 54):
    seq_timestamp = df_n2[f'CallContent.Seq{i}.Timestamp']
    seq_timestamp = seq_timestamp.fillna('')  # Replace NaN values with empty strings
    seq_timestamp = seq_timestamp.apply(parse_timestamp)
    delta_list.append(seq_timestamp.diff())

delta_df = pd.DataFrame(delta_list).transpose()
delta_df.columns = [f'Delta{i}' for i in range(1, 54)]

df_n2 = pd.concat([df_n2, delta_df], axis=1)

total_delta = delta_df.sum(axis=1)
df_n2['Total Delta'] = total_delta

print(df_n2['Total Delta'])
# Out:
# 0        0 days 00:00:00
# 1        0 days 02:52:00
# 2        0 days 01:54:18
# 3      -1 days +22:42:45
# 4      -1 days +23:35:54
#              ...
# 181      0 days 00:00:00
# 182      0 days 00:00:00
# 183      0 days 00:00:00
# 184      0 days 00:00:00
# 185   3686 days 04:05:03
# Name: Total Delta, Length: 186, dtype: timedelta64[ns]

# %%
df_n2.groupby('call_month')['Total Delta'].mean()
# Out:
# call_month
# December    -60 days +22:52:58.409090909
# February               796 days 00:26:07
# March        187 days 17:15:57.818181818
# November      22 days 23:41:13.666666666
# October                564 days 23:22:55
# September   -69 days +01:42:41.695652174
# Name: Total Delta, dtype: timedelta64[ns]

# %% [markdown]
# #Reading Records as rows for each sequence of calls

# %%
df.columns.str.strip()
# Out:
# Index(['Metadata', 'Caller', 'Receiver', 'Timestamp',
#        'CallContent.Seq1.CallerContent', 'CallContent.Seq1.ReceiverContent',
#        'CallContent.Seq1.Timestamp', 'CallContent.Seq2.CallerContent',
#        'CallContent.Seq2.ReceiverContent', 'CallContent.Seq2.Timestamp',
#        ...
#        'Caller_Sentiment_Score', 'emot_model', 'Caller_Emotion',
#        'Caller_Emotion_Score', 'Receiver_Sentiment',
#        'Receiver_Sentiment_Score', 'Receiver_Emotion',
#        'Receiver_Emotion_Score', 'totalwords_receiver', 'totalwords_caller'],
#       dtype='object', length=197)

# %%
df1 = df
df1.head()
# Out:
#   Metadata       Caller                           Receiver  Timestamp  \
# 0    value        Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1    value      no_name  Crafton Family Practice (dominic) 2023-12-04
# 2    value  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3    value     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4    value    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
#
#                       CallContent.Seq1.CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                             Hello?
#
#                     CallContent.Seq1.ReceiverContent  \
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...
#
#   CallContent.Seq1.Timestamp  \
# 0       2023_Dec_04_13:49:18
# 1       2023_Dec_04_14:46:53
# 2       2023_Dec_04_15:24:59
# 3        2023_12_04_14:59:14
# 4        2023_12_04_14:51:12
#
#                       CallContent.Seq2.CallerContent  \
# 0                           Sure, January 1st, 1997.
# 1  pardon me yeah can you give me a minute let me...
# 2                                   Okay, thank you.
# 3                                   Okay. Thank you.
# 4  Yes, I'd like to make an appointment for follo...
#
#                     CallContent.Seq2.ReceiverContent  \
# 0  Yeah, sure. Could I take the patient's date of...
# 1  sure I'm sorry yeah I'm really sorry mom all t...
# 2  Okay, one moment. Let me shout for you to the ...
# 3  Sure. Regarding that, I need to transfer you t...
# 4  Sure. Would you like to meet the doctor in per...
#
#   CallContent.Seq2.Timestamp  ... Caller_Sentiment_Score  \
# 0       2023_Dec_04_13:49:32  ...               0.998999
# 1       2023_Dec_04_14:46:53  ...               0.991963
# 2       2023_Dec_04_15:24:59  ...               0.995155
# 3        2023_12_04_14:59:14  ...               0.998020
# 4        2023_12_04_14:51:12  ...               0.994520
#
#                                           emot_model Caller_Emotion  \
# 0    [{'label': 'joy', 'score': 0.9963880777359009}]            joy
# 1  [{'label': 'sadness', 'score': 0.9896580576896...            joy
# 2    [{'label': 'joy', 'score': 0.8701915144920349}]            joy
# 3    [{'label': 'joy', 'score': 0.9637673497200012}]            joy
# 4    [{'label': 'joy', 'score': 0.9980828762054443}]            joy
#
#   Caller_Emotion_Score Receiver_Sentiment Receiver_Sentiment_Score  \
# 0             0.998286           POSITIVE                 0.997877
# 1             0.985529           NEGATIVE                 0.980291
# 2             0.995210           POSITIVE                 0.824704
# 3             0.996436           POSITIVE                 0.996502
# 4             0.913450           POSITIVE                 0.999104
#
#   Receiver_Emotion Receiver_Emotion_Score totalwords_receiver  \
# 0              joy               0.996388                  82
# 1          sadness               0.989658                  58
# 2              joy               0.870192                 294
# 3              joy               0.963767                 143
# 4              joy               0.998083                 135
#
#   totalwords_caller
# 0                65
# 1                44
# 2                85
# 3               152
# 4                88
#
# [5 rows x 197 columns]

# %%
id_vars = ['Caller', 'Receiver', 'Timestamp']
value_vars = [col for col in df1.columns if col.startswith('CallContent.Seq')]
df_long = pd.melt(df1, id_vars=id_vars, value_vars=value_vars, var_name='CallSequence', value_name=('CallContent'))
df_long
# Out:
#               Caller                           Receiver  Timestamp  \
# 0              Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1            no_name  Crafton Family Practice (dominic) 2023-12-04
# 2        Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3           Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4          Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
# ...              ...                                ...        ...
# 31987        No name                            Dominic        NaT
# 31988  Marilyn Hardy                            Dominic 2023-09-20
# 31989        No name                            Dominic        NaT
# 31990        Allison                              Kumar 2023-10-26
# 31991    Mary Shealy                             Carole 2024-10-29
#
#                                CallSequence  \
# 0            CallContent.Seq1.CallerContent
# 1            CallContent.Seq1.CallerContent
# 2            CallContent.Seq1.CallerContent
# 3            CallContent.Seq1.CallerContent
# 4            CallContent.Seq1.CallerContent
# ...                                     ...
# 31987  CallContent.Seq5.OtherSpeakerContent
# 31988  CallContent.Seq5.OtherSpeakerContent
# 31989  CallContent.Seq5.OtherSpeakerContent
# 31990  CallContent.Seq5.OtherSpeakerContent
# 31991  CallContent.Seq5.OtherSpeakerContent
#
#                                              CallContent
# 0      Hi, I just want to double check. My daughter h...
# 1      last known thanks for calling corruption from ...
# 2      I'd like to speak out with the front office ab...
# 3      Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4                                                 Hello?
# ...                                                  ...
# 31987                                                NaN
# 31988                                                NaN
# 31989                                                NaN
# 31990                                                NaN
# 31991                                                NaN
#
# [31992 rows x 5 columns]

# %%
df_long2 = df1.melt(id_vars=['Caller', 'Receiver', 'Timestamp', 'call_weekday',  'CallerContent', 'ReceiverContent', 'Caller_Emotion', 'Receiver_Emotion'],
                 value_vars=[f'CallContent.Seq{i}.ReceiverContent' for i in range(1, 55)],
                 var_name='Sequence', value_name='ReciverContent')




df_long2
# Out:
#               Caller                           Receiver  Timestamp  \
# 0              Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1            no_name  Crafton Family Practice (dominic) 2023-12-04
# 2        Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3           Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4          Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
# ...              ...                                ...        ...
# 10039        No name                            Dominic        NaT
# 10040  Marilyn Hardy                            Dominic 2023-09-20
# 10041        No name                            Dominic        NaT
# 10042        Allison                              Kumar 2023-10-26
# 10043    Mary Shealy                             Carole 2024-10-29
#
#       call_weekday                                      CallerContent  \
# 0           Monday  Hi, I just want to double check. My daughter h...
# 1           Monday  last known thanks for calling corruption from ...
# 2           Monday  I'd like to speak out with the front office ab...
# 3           Monday  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4           Monday  Hello? Yes, I'd like to make an appointment fo...
# ...            ...                                                ...
# 10039          NaN
# 10040    Wednesday  You sent me to the front office. She put me on...
# 10041          NaN
# 10042     Thursday  Hi, yes. I'd like to make an appointment with ...
# 10043      Tuesday  Good morning. My name is Mary Shealy, and I ne...
#
#                                          ReceiverContent Caller_Emotion  \
# 0      Good afternoon, this is Crafton Family Practic...            joy
# 1      is this you for the day hi I was wondering if ...            joy
# 2      Good afternoon. Thanks for calling Grafton Fam...            joy
# 3      Good afternoon. Thanks for calling Crofton Fam...            joy
# 4      Good afternoon, this is Kumaran from Family Pr...            joy
# ...                                                  ...            ...
# 10039                                                             anger
# 10040  No, ma'am. It's not like that. Yes, she was on...          anger
# 10041                                                             anger
# 10042  Good morning. Thanks for calling Carlson Famil...            joy
# 10043  Would you like to meet the doctor in person, o...            joy
#
#       Receiver_Emotion                           Sequence  \
# 0                  joy   CallContent.Seq1.ReceiverContent
# 1              sadness   CallContent.Seq1.ReceiverContent
# 2                  joy   CallContent.Seq1.ReceiverContent
# 3                  joy   CallContent.Seq1.ReceiverContent
# 4                  joy   CallContent.Seq1.ReceiverContent
# ...                ...                                ...
# 10039            anger  CallContent.Seq54.ReceiverContent
# 10040              joy  CallContent.Seq54.ReceiverContent
# 10041            anger  CallContent.Seq54.ReceiverContent
# 10042              joy  CallContent.Seq54.ReceiverContent
# 10043              joy  CallContent.Seq54.ReceiverContent
#
#                                           ReciverContent
# 0      Good afternoon, this is Crafton Family Practic...
# 1      is this you for the day hi I was wondering if ...
# 2      Good afternoon. Thanks for calling Grafton Fam...
# 3      Good afternoon. Thanks for calling Crofton Fam...
# 4      Good afternoon, this is Kumaran from Family Pr...
# ...                                                  ...
# 10039                                                NaN
# 10040                                                NaN
# 10041                                                NaN
# 10042                                                NaN
# 10043                                                NaN
#
# [10044 rows x 10 columns]

# %%
df_long2 = df1.melt(id_vars=['Caller', 'Receiver', 'Timestamp','CallerContent','ReceiverContent'],
                 value_vars=[f'CallContent.Seq{i}.ReceiverContent' for i in range(1, 55)],
                 var_name='Sequence', value_name='ReciverContent')


# Reset index
df_long2.reset_index(drop=True, inplace=True)

df_long2
# Out:
#               Caller                           Receiver  Timestamp  \
# 0              Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1            no_name  Crafton Family Practice (dominic) 2023-12-04
# 2        Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3           Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4          Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
# ...              ...                                ...        ...
# 10039        No name                            Dominic        NaT
# 10040  Marilyn Hardy                            Dominic 2023-09-20
# 10041        No name                            Dominic        NaT
# 10042        Allison                              Kumar 2023-10-26
# 10043    Mary Shealy                             Carole 2024-10-29
#
#                                            CallerContent  \
# 0      Hi, I just want to double check. My daughter h...
# 1      last known thanks for calling corruption from ...
# 2      I'd like to speak out with the front office ab...
# 3      Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4      Hello? Yes, I'd like to make an appointment fo...
# ...                                                  ...
# 10039
# 10040  You sent me to the front office. She put me on...
# 10041
# 10042  Hi, yes. I'd like to make an appointment with ...
# 10043  Good morning. My name is Mary Shealy, and I ne...
#
#                                          ReceiverContent  \
# 0      Good afternoon, this is Crafton Family Practic...
# 1      is this you for the day hi I was wondering if ...
# 2      Good afternoon. Thanks for calling Grafton Fam...
# 3      Good afternoon. Thanks for calling Crofton Fam...
# 4      Good afternoon, this is Kumaran from Family Pr...
# ...                                                  ...
# 10039
# 10040  No, ma'am. It's not like that. Yes, she was on...
# 10041
# 10042  Good morning. Thanks for calling Carlson Famil...
# 10043  Would you like to meet the doctor in person, o...
#
#                                 Sequence  \
# 0       CallContent.Seq1.ReceiverContent
# 1       CallContent.Seq1.ReceiverContent
# 2       CallContent.Seq1.ReceiverContent
# 3       CallContent.Seq1.ReceiverContent
# 4       CallContent.Seq1.ReceiverContent
# ...                                  ...
# 10039  CallContent.Seq54.ReceiverContent
# 10040  CallContent.Seq54.ReceiverContent
# 10041  CallContent.Seq54.ReceiverContent
# 10042  CallContent.Seq54.ReceiverContent
# 10043  CallContent.Seq54.ReceiverContent
#
#                                           ReciverContent
# 0      Good afternoon, this is Crafton Family Practic...
# 1      is this you for the day hi I was wondering if ...
# 2      Good afternoon. Thanks for calling Grafton Fam...
# 3      Good afternoon. Thanks for calling Crofton Fam...
# 4      Good afternoon, this is Kumaran from Family Pr...
# ...                                                  ...
# 10039                                                NaN
# 10040                                                NaN
# 10041                                                NaN
# 10042                                                NaN
# 10043                                                NaN
#
# [10044 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Columns: 197 entries, Metadata to totalwords_caller
# dtypes: datetime64[ns](1), float64(4), int64(2), object(190)
# memory usage: 286.4+ KB

# %% [markdown]
# #Business Insights

# %%
#Productivity of call center employee - based on number of calls by employee
##(good and bad files combined)
df.Receiver.value_counts(ascending= False)
# Out:
# Receiver
# Dominic                                  62
# Kumar                                    24
# Dominic (Crofton Family Practice)        10
# Kathy                                     8
# Dominic from Crofton Family Practice      8
# Kumaran (Crofton Family Practice)         6
# Dominique                                 6
# Brandi                                    4
# Brandy                                    4
# Kathy from Crofton Family Practice        4
# Kumar from Crofton Family Practice        4
# Kathy from Crosswind Family Practice      4
# Kumar from Crawford Family Practice       2
# Dominic from Robson Family Practice       2
# No Name                                   2
# Dominic from Grobson Family Practice      2
# Dominic from Coffin Family Practice       2
# Dominic from CrossFit Family Practice     2
# Dominic from Grafton Family Practice      2
# Crafton Family Practice (Kumaran)         2
# Kathy from Proud and Family Practice      2
# Crafton Family Practice (dominic)         2
# Dominic (Crossroads Family Practice)      2
# Kumaran (Robson Family Practice)          2
# Kumaran (Carlston Family Practice)        2
# David (Crossroads Family Practice)        2
# Kumaran (Grafton Family Practice)         2
# Carole                                    2
# Name: count, dtype: int64

# %% [markdown]
# #Streamlit

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00

# %%
# !npm install localtunnel
# Out:
# added 22 packages, and audited 23 packages in 3s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.127.126.47

# %%
df_long3 = df1.melt(id_vars=['Caller', 'Receiver', 'Timestamp', 'call_weekday',  'CallerContent', 'ReceiverContent', 'Caller_Emotion', 'Receiver_Emotion'],
                 value_vars=[f'CallContent.Seq{i}.ReceiverContent' for i in range(1, 55)],
                 var_name='Sequence', value_name='ReciverContent')
df_long3.columns
# Out:
# Index(['Caller', 'Receiver', 'Timestamp', 'call_weekday', 'CallerContent',
#        'ReceiverContent', 'Caller_Emotion', 'Receiver_Emotion', 'Sequence',
#        'ReciverContent'],
#       dtype='object')

# %%
df_long3.head()
# Out:
#         Caller                           Receiver  Timestamp call_weekday  \
# 0        Emily  Crafton Family Practice (Kumaran) 2023-12-04       Monday
# 1      no_name  Crafton Family Practice (dominic) 2023-12-04       Monday
# 2  Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04       Monday
# 3     Ed Jones  Dominic (Crofton Family Practice) 2023-12-04       Monday
# 4    Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04       Monday
#
#                                        CallerContent  \
# 0  Hi, I just want to double check. My daughter h...
# 1  last known thanks for calling corruption from ...
# 2  I'd like to speak out with the front office ab...
# 3  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4  Hello? Yes, I'd like to make an appointment fo...
#
#                                      ReceiverContent Caller_Emotion  \
# 0  Good afternoon, this is Crafton Family Practic...            joy
# 1  is this you for the day hi I was wondering if ...            joy
# 2  Good afternoon. Thanks for calling Grafton Fam...            joy
# 3  Good afternoon. Thanks for calling Crofton Fam...            joy
# 4  Good afternoon, this is Kumaran from Family Pr...            joy
#
#   Receiver_Emotion                          Sequence  \
# 0              joy  CallContent.Seq1.ReceiverContent
# 1          sadness  CallContent.Seq1.ReceiverContent
# 2              joy  CallContent.Seq1.ReceiverContent
# 3              joy  CallContent.Seq1.ReceiverContent
# 4              joy  CallContent.Seq1.ReceiverContent
#
#                                       ReciverContent
# 0  Good afternoon, this is Crafton Family Practic...
# 1  is this you for the day hi I was wondering if ...
# 2  Good afternoon. Thanks for calling Grafton Fam...
# 3  Good afternoon. Thanks for calling Crofton Fam...
# 4  Good afternoon, this is Kumaran from Family Pr...

# %%
# %%writefile app.py



import streamlit as st
df_d3= df_long3

st.write("# Customers Call Data")

# Input for caller name
input_caller = st.text_input("Enter a caller name")

if input_caller:
    filtered_df = df_d3[df_d3['Caller'] == input_caller][['Caller_Emotion', 'Receiver']]
    if not filtered_df.empty:
        st.write(filtered_df)
    else:
        st.write("No records found for the entered caller name.")
# Out:
# Overwriting app.py

# %%
# Out:
# Overwriting app.py

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# 34.127.126.47

# %%
df_long3.to_json('df_long3.json')
df_long3
# Out:
#               Caller                           Receiver  Timestamp  \
# 0              Emily  Crafton Family Practice (Kumaran) 2023-12-04
# 1            no_name  Crafton Family Practice (dominic) 2023-12-04
# 2        Brian Fryer  Kumaran (Grafton Family Practice) 2023-12-04
# 3           Ed Jones  Dominic (Crofton Family Practice) 2023-12-04
# 4          Elizabeth  Kumaran (Crofton Family Practice) 2023-12-04
# ...              ...                                ...        ...
# 10039        No name                            Dominic        NaT
# 10040  Marilyn Hardy                            Dominic 2023-09-20
# 10041        No name                            Dominic        NaT
# 10042        Allison                              Kumar 2023-10-26
# 10043    Mary Shealy                             Carole 2024-10-29
#
#       call_weekday                                      CallerContent  \
# 0           Monday  Hi, I just want to double check. My daughter h...
# 1           Monday  last known thanks for calling corruption from ...
# 2           Monday  I'd like to speak out with the front office ab...
# 3           Monday  Hi, this is Ed Jones. I'm a patient at Dr. Wil...
# 4           Monday  Hello? Yes, I'd like to make an appointment fo...
# ...            ...                                                ...
# 10039          NaN
# 10040    Wednesday  You sent me to the front office. She put me on...
# 10041          NaN
# 10042     Thursday  Hi, yes. I'd like to make an appointment with ...
# 10043      Tuesday  Good morning. My name is Mary Shealy, and I ne...
#
#                                          ReceiverContent Caller_Emotion  \
# 0      Good afternoon, this is Crafton Family Practic...            joy
# 1      is this you for the day hi I was wondering if ...            joy
# 2      Good afternoon. Thanks for calling Grafton Fam...            joy
# 3      Good afternoon. Thanks for calling Crofton Fam...            joy
# 4      Good afternoon, this is Kumaran from Family Pr...            joy
# ...                                                  ...            ...
# 10039                                                             anger
# 10040  No, ma'am. It's not like that. Yes, she was on...          anger
# 10041                                                             anger
# 10042  Good morning. Thanks for calling Carlson Famil...            joy
# 10043  Would you like to meet the doctor in person, o...            joy
#
#       Receiver_Emotion                           Sequence  \
# 0                  joy   CallContent.Seq1.ReceiverContent
# 1              sadness   CallContent.Seq1.ReceiverContent
# 2                  joy   CallContent.Seq1.ReceiverContent
# 3                  joy   CallContent.Seq1.ReceiverContent
# 4                  joy   CallContent.Seq1.ReceiverContent
# ...                ...                                ...
# 10039            anger  CallContent.Seq54.ReceiverContent
# 10040              joy  CallContent.Seq54.ReceiverContent
# 10041            anger  CallContent.Seq54.ReceiverContent
# 10042              joy  CallContent.Seq54.ReceiverContent
# 10043              joy  CallContent.Seq54.ReceiverContent
#
#                                           ReciverContent
# 0      Good afternoon, this is Crafton Family Practic...
# 1      is this you for the day hi I was wondering if ...
# 2      Good afternoon. Thanks for calling Grafton Fam...
# 3      Good afternoon. Thanks for calling Crofton Fam...
# 4      Good afternoon, this is Kumaran from Family Pr...
# ...                                                  ...
# 10039                                                NaN
# 10040                                                NaN
# 10041                                                NaN
# 10042                                                NaN
# 10043                                                NaN
#
# [10044 rows x 10 columns]

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the DataFrame from the JSON file
df_long3 = pd.read_json('df_long3.json')

st.write("# Customers Call Data")

# Input for caller name
input_caller = st.text_input("Enter a caller name")

if input_caller:
    # Filtering the data
    filtered_df_caller = df_long3[df_long3['Caller'].str.contains(input_caller, case=False, na=False)]

    if not filtered_df_caller.empty:
        # Displaying the records
        st.write("Caller Emotions, Receivers, Timestamp, and Day")
        st.write(filtered_df_caller[['Caller_Emotion', 'Receiver', 'Timestamp', 'call_weekday','CallerContent']])

        # Create a plot
        fig, ax = plt.subplots()
        sns.scatterplot(data=filtered_df_caller, x='Caller_Emotion', y='Receiver_Emotion', ax=ax)
        plt.xticks(rotation=45)
        plt.yticks(rotation=45)
        st.pyplot(fig)
    else:
        st.write("No records found for the entered caller name.")

# Input for receiver name
input_receiver = st.text_input("Enter a receiver name")

if input_receiver:
    # Filter the DataFrame based on partial matches for the receiver name
    filtered_df_receiver = df_long3[df_long3['Receiver'].str.contains(input_receiver, case=False, na=False)]

    if not filtered_df_receiver.empty:
        # Displaying the records
        st.write("Receiver Emotions, Callers, Timestamp, and Day")
        st.write(filtered_df_receiver[['Receiver_Emotion', 'Caller', 'Timestamp', 'call_weekday','ReciverContent']])
    else:
        st.write("No records found for the entered receiver name.")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.127.126.47:8501
#
# your url is: https://good-pears-follow.loca.lt
#   Stopping...
# ^C
